# %%
import pandas as pd 
import jieba 
import os
import time 
import math

# %%
class Medical_Research:

    def __init__(self, scale=1):  
        self.docs = []
        self.load_data()
        self.docs *= scale
        self.cache = {} # 增加词典作为缓存
        self.vocab = set()
        self.df = {} # 存储每个词的词频
        self.avgdl = 0 
        self.sum_N = len(self.docs) # 表示文本集合中文本的总数量
        self.dictionary_prepare()
        self.build_cache()
        
    def load_data(self):
        time_start=time.time() # time
        
        final_homework = pd.read_csv('data/medical_text_data.csv',encoding='gbk',names=['症状','诊断'])
        final_homework = final_homework.fillna('') # 诊断有一个值为空
        data = pd.concat( [final_homework['症状'],final_homework['诊断']],axis=0).reset_index(drop=True)
        self.docs = [d.replace(' ','') for d in data.values.tolist()]
        
        time_end=time.time() # time
        print('【load_data】time cost:',time_end-time_start,'s') # time
    
    def dictionary_prepare(self):
        time_start=time.time() # time
        
        jieba.load_userdict('dictionary/dict_medical.txt')
        jieba.load_userdict('dictionary/add_dict.txt')
        # 医学辞典
        jieba.load_userdict('dictionary/chinese_medical_words-master/emr.txt')
        jieba.load_userdict('dictionary/chinese_medical_words-master/medicine.txt')
        jieba.load_userdict('dictionary/chinese_medical_words-master/properties.txt')

        time_end=time.time() # time
        print('【dictionary_prepare】time cost:',time_end-time_start,'s') # time
    
    def cut(self,phrase,cut_all=False):
        if cut_all:
            return jieba.cut(phrase, cut_all=True)
        return jieba.cut(phrase)
        
    def build_cache(self):
        time_start=time.time() # time
        
        doc_id = 0
        doc_length_sum = 0
        for doc in self.docs: 
            doc_length_sum += len(doc)
            for word in set(self.cut(doc,cut_all=True)) :# 一句话中一个词只算一次 16.
#             for word in set(self.cut(doc,cut_all=False)) :# 一句话中一个词只算一次 32.8
                result_item = doc_id
                if word not in self.vocab:
                    self.cache[word] = set([result_item])
                    self.df[word] = 1
                    self.vocab.add(word)
                else:
                    self.cache[word].add(result_item) 
                    self.df[word] += 1
            doc_id += 1
        self.avgdl = doc_length_sum / self.sum_N
        
        time_end=time.time() # time
        print('【build_cache】time cost:',time_end-time_start,'s') # time
        
    def score(self,doc,query_lst,k1=2, b=0.75): # BM25
        score = 0
        cut_query = []
        if len(query_lst) == 1: # 属于单个名词的查询
            cut_query = list(self.cut(query_lst[0]))
        elif len(query_lst) > 1: # 属于布尔复合查询
            for i in range(len(query_lst)):
                cut_query += list(self.cut(query_lst[i]))
        
        dl = len(doc)
        for keyword in cut_query:
            if keyword in doc: # doc中的每个词只计算一次
                f = doc.count(keyword)
                tf = f*(k1+1)/(f+k1*(1-b+b*(dl/self.avgdl)))
                idf = math.log10((self.sum_N-self.df[keyword]+0.5)/(self.df[keyword] + 0.5))
                score +=  tf * idf
        return score 
    
    def rank(self, query_lst, result_set):
        # 对简单查询和布尔查询检索结果根据score进行排序
        result = []
        for doc_id in result_set:
            result.append([doc_id, self.score(self.docs[doc_id], query_lst)])
        result.sort(key=lambda x:x[1], reverse=True)
        return result 
    
    def get_phrase_match(self,phrase):
        result = None
        cut_phrase = self.cut(phrase)
        cache_temp = self.cache
        for keyword in cut_phrase:
            if keyword in cache_temp:
                if result == None:
                    result = cache_temp[keyword]
                else:
                    result = result & cache_temp[keyword]
            else:
                result = set([])
        if result is None:
            result = set([])
        return result
    
    def conv_query(self,query):
        query += ' '
        qlen = len(query)
        result_parts = []
        idx = 0
        cache = ''
        keywords = list()
        while idx < qlen:
            if query[idx] in ('(',')',' '):
                if cache != '':
                    if cache.lower() == 'and':
                        result_parts.append('&')
                    elif cache.lower() == 'or':
                        result_parts.append('|')
                    elif cache.lower() == 'not':
                        result_parts.append('-')
                    else:
                        result_parts.append("self.get_phrase_match('{}')".format(cache))
                        keywords.append(cache)
                    cache = ''
                result_parts.append(query[idx])
            else:
                cache += query[idx]
            idx += 1
        return "".join(result_parts),keywords
    
    def search(self,query):
        # 处理布尔查询语句，分词，处理'(华为 or 苹果) and 手机 ' 的形式
        if ('and' in query) or ('or' in query) or ('not' in query):
            result_parts, query_keywords = self.conv_query(query)
            result_set = eval(result_parts)
        # 处理单关键词查询
        else:
            result_set = self.get_phrase_match(query)
            query_keywords = [query]
            
        sort_result = self.rank(query_keywords,result_set)
        return sort_result   
    
    def rener_research_result(self,query,result_print=False):
        time_start=time.time() # time
        results = self.search(query)
        print('The length of results is ',len(results))
        time_end=time.time() # time
        print('【search】time cost:',time_end-time_start,'s\n\n') # time
        
        if result_print:
            for result in results:
                sentence = self.docs[result[0]]
                for keyword in self.cut(query):
                    if keyword not in ('(',')',' '):
                        sentence = sentence.replace(keyword,'【{}】'.format(keyword)).strip()
                print("doc_id:{}, score:{},\ndoc:{}\n".format(result[0],result[1],sentence))

# %%
# %prun mr = Medical_Research()
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\DELL\AppData\Local\Temp\jieba.cache
# 【load_data】time cost: 0.34012722969055176 s
# Loading model cost 0.709 seconds.
# Prefix dict has been built successfully.
# 【dictionary_prepare】time cost: 4.425678968429565 s
# 【build_cache】time cost: 20.392681121826172 s
#          32397608 function calls (32397442 primitive calls) in 25.164 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#    584117    7.956    0.000    8.894    0.000 __init__.py:180(get_DAG)
#         1    3.501    3.501   20.393   20.393 2666504946.py:44(build_cache)
#   3406411    3.202    0.000   12.503    0.000 __init__.py:198(__cut_all)
#   3917886    2.638    0.000   18.819    0.000 __init__.py:289(cut)
#   2668857    1.249    0.000    1.249    0.000 {method 'match' of 're.Pattern' objects}
#   7307980    0.753    0.000    0.753    0.000 {method 'append' of 'list' objects}
#         1    0.707    0.707    0.707    0.707 {built-in method marshal.load}
#   2767189    0.624    0.000    0.624    0.000 {method 'add' of 'set' objects}
#    639361    0.560    0.000    0.560    0.000 {method 'split' of 're.Pattern' objects}
# 4982893/4982869    0.478    0.000    0.478    0.000 {built-in method builtins.len}
#    816230    0.469    0.000    0.645    0.000 __init__.py:177(<genexpr>)
#    514517    0.316    0.000    0.511    0.000 _compat.py:73(<lambda>)
#     69600    0.304    0.000    2.999    0.000 __init__.py:445(suggest_freq)
#     69600    0.275    0.000    1.161    0.000 __init__.py:172(calc)
#     69600    0.267    0.000    3.325    0.000 __init__.py:418(add_word)
#         1    0.267    0.267    0.267    0.267 {method 'read_low_memory' of 'pandas._libs.parsers.TextReader' objects}
#    238031    0.244    0.000    2.257    0.000 __init__.py:226(__cut_DAG_NO_HMM)
#    397581    0.232    0.000    0.877    0.000 {built-in method builtins.max}
#         5    0.206    0.041    4.425    0.885 __init__.py:380(load_userdict)
#    726384    0.147    0.000    0.147    0.000 {method 'get' of 'dict' objects}
#    723322    0.142    0.000    0.853    0.000 __init__.py:168(check_initialized)
#    514518    0.111    0.000    0.111    0.000 {built-in method builtins.iter}
#    557853    0.104    0.000    0.104    0.000 {built-in method math.log}
#    514523    0.085    0.000    0.085    0.000 {method 'items' of 'dict' objects}
#    191878    0.080    0.000    0.105    0.000 _compat.py:76(strdecode)
# 331790/331788    0.050    0.000    0.050    0.000 {built-in method builtins.isinstance}
#     52678    0.041    0.000    0.041    0.000 2666504946.py:39(cut)
#     69620    0.034    0.000    0.034    0.000 {method 'decode' of 'bytes' objects}
#     52696    0.026    0.000    0.026    0.000 {method 'replace' of 'str' objects}
#     69600    0.014    0.000    0.014    0.000 {method 'groups' of 're.Match' objects}
#     69620    0.013    0.000    0.013    0.000 {method 'strip' of 'bytes' objects}
#         1    0.013    0.013    0.013    0.013 c_parser_wrapper.py:45(__init__)
#     69620    0.012    0.000    0.012    0.000 {method 'lstrip' of 'str' objects}
#         1    0.011    0.011    0.037    0.037 2666504946.py:21(<listcomp>)
#         1    0.007    0.007    0.007    0.007 {pandas._libs.missing.isnaobj2d}
#         1    0.004    0.004   25.164   25.164 2666504946.py:3(__init__)
#        13    0.003    0.000    0.003    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#        10    0.002    0.000    0.002    0.000 {built-in method nt.stat}
#         7    0.002    0.000    0.002    0.000 {built-in method io.open}
#         2    0.002    0.001    0.002    0.001 {method 'copy' of 'numpy.ndarray' objects}
#        35    0.001    0.000    0.001    0.000 {method 'acquire' of '_thread.lock' objects}
#         1    0.001    0.001    0.340    0.340 2666504946.py:15(load_data)
#        15    0.001    0.000    0.001    0.000 socket.py:357(send)
#         1    0.001    0.001    0.289    0.289 readers.py:539(_read)
#         1    0.001    0.001    0.001    0.001 managers.py:2060(_stack_arrays)
#         1    0.001    0.001    0.001    0.001 {method 'tolist' of 'numpy.ndarray' objects}
#         1    0.001    0.001    0.001    0.001 {method 'close' of 'pandas._libs.parsers.TextReader' objects}
#         1    0.000    0.000    4.426    4.426 2666504946.py:26(dictionary_prepare)
#        12    0.000    0.000    0.000    0.000 {built-in method numpy.empty}
#         1    0.000    0.000    0.001    0.001 c_parser_wrapper.py:344(_concatenate_chunks)
#        45    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:96(_path_join)
#         8    0.000    0.000    0.000    0.000 {pandas._libs.lib.maybe_convert_objects}
#         1    0.000    0.000    0.269    0.269 c_parser_wrapper.py:215(read)
#         1    0.000    0.000   25.164   25.164 {built-in method builtins.exec}
#      74/8    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#         9    0.000    0.000    0.002    0.000 <frozen importlib._bootstrap_external>:1536(find_spec)
#       7/6    0.000    0.000    0.002    0.000 series.py:323(__init__)
#        22    0.000    0.000    0.001    0.000 iostream.py:525(write)
#         1    0.000    0.000    0.290    0.290 readers.py:584(read_csv)
#         1    0.000    0.000    0.000    0.000 readers.py:1018(_clean_options)
#       6/3    0.000    0.000    0.000    0.000 base.py:397(__new__)
#        10    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#         9    0.000    0.000    0.000    0.000 construction.py:470(sanitize_array)
#         1    0.000    0.000    0.017    0.017 readers.py:886(__init__)
#         2    0.000    0.000    0.000    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#        15    0.000    0.000    0.001    0.000 iostream.py:209(schedule)
#         9    0.000    0.000    0.000    0.000 generic.py:239(__init__)
#         4    0.000    0.000    0.000    0.000 __init__.py:283(__init__)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.locals}
#         1    0.000    0.000    0.003    0.003 <frozen importlib._bootstrap>:921(_find_spec)
#         1    0.000    0.000    0.000    0.000 {built-in method numpy.arange}
#         1    0.000    0.000    0.002    0.002 <frozen importlib._bootstrap_external>:1399(_get_spec)
#         1    0.000    0.000    0.711    0.711 __init__.py:93(initialize)
#         1    0.000    0.000    0.003    0.003 <frozen importlib._bootstrap>:1022(_find_and_load)
#         6    0.000    0.000    0.000    0.000 blocks.py:2041(new_block)
#         1    0.000    0.000    0.000    0.000 {method 'close' of '_io.TextIOWrapper' objects}
#       102    0.000    0.000    0.000    0.000 generic.py:43(_check)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:179(_get_module_lock)
#         1    0.000    0.000    0.000    0.000 sre_parse.py:493(_parse)
#         6    0.000    0.000    0.000    0.000 generic.py:5517(__finalize__)
#       2/1    0.000    0.000    0.000    0.000 sre_compile.py:71(_compile)
#         1    0.000    0.000    0.016    0.016 readers.py:1192(_make_engine)
#        27    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_list_like}
#       5/4    0.000    0.000    0.301    0.075 _decorators.py:302(wrapper)
#         1    0.000    0.000    0.000    0.000 readers.py:940(_get_options_with_defaults)
#        45    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:119(<listcomp>)
#        38    0.000    0.000    0.000    0.000 common.py:1587(_is_dtype_type)
#       102    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#         2    0.000    0.000    0.003    0.001 common.py:1112(_is_binary_mode)
#       139    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         1    0.000    0.000    0.000    0.000 readers.py:1428(_refine_defaults_read)
#         3    0.000    0.000    0.001    0.000 {built-in method builtins.print}
#        19    0.000    0.000    0.000    0.000 threading.py:1162(is_alive)
#         1    0.000    0.000    0.003    0.003 common.py:604(get_handle)
#         1    0.000    0.000    0.000    0.000 {method '__exit__' of '_io._IOBase' objects}
#         4    0.000    0.000    0.002    0.000 iostream.py:470(flush)
#         7    0.000    0.000    0.000    0.000 ntpath.py:124(splitdrive)
#        61    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#         4    0.000    0.000    0.000    0.000 __init__.py:1549(findCaller)
#        11    0.000    0.000    0.000    0.000 generic.py:5577(__setattr__)
#         1    0.000    0.000    0.000    0.000 base.py:2232(is_unique)
#         3    0.000    0.000    0.001    0.000 base.py:672(_with_infer)
#        10    0.000    0.000    0.000    0.000 common.py:1429(is_extension_array_dtype)
#         1    0.000    0.000    0.001    0.001 concat.py:74(concat_compat)
#         1    0.000    0.000    0.001    0.001 concat.py:368(__init__)
#         9    0.000    0.000    0.000    0.000 construction.py:695(_try_cast)
#         2    0.000    0.000    0.000    0.000 readers.py:486(validate_integer)
#         5    0.000    0.000    0.000    0.000 ntpath.py:180(split)
#       144    0.000    0.000    0.000    0.000 {method 'endswith' of 'str' objects}
#         8    0.000    0.000    0.000    0.000 numeric.py:289(full)
#         4    0.000    0.000    0.002    0.000 threading.py:582(wait)
#         1    0.000    0.000    0.001    0.001 range.py:850(_concat)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:100(acquire)
#         1    0.000    0.000    0.000    0.000 blocks.py:490(_split)
#        22    0.000    0.000    0.000    0.000 iostream.py:436(_is_master_process)
#         4    0.000    0.000    0.000    0.000 threading.py:236(__init__)
#         2    0.000    0.000    0.000    0.000 frame.py:3463(__getitem__)
#         4    0.000    0.000    0.002    0.001 __init__.py:1455(debug)
#         1    0.000    0.000    0.003    0.003 construction.py:425(dict_to_mgr)
#         1    0.000    0.000    0.003    0.003 __init__.py:108(import_module)
#         1    0.000    0.000    0.000    0.000 base_parser.py:83(__init__)
#         1    0.000    0.000    0.000    0.000 {pandas._libs.lib.infer_dtype}
#        22    0.000    0.000    0.001    0.000 iostream.py:455(_schedule_flush)
#         5    0.000    0.000    0.000    0.000 _decorators.py:214(_format_argument_list)
#         1    0.000    0.000    0.271    0.271 readers.py:1244(read)
#        11    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1356(_path_importer_cache)
#         1    0.000    0.000    0.002    0.002 concat.py:544(get_result)
#         4    0.000    0.000    0.002    0.000 threading.py:288(wait)
#         1    0.000    0.000    0.003    0.003 _optional.py:87(import_optional_dependency)
#       140    0.000    0.000    0.000    0.000 {method 'rstrip' of 'str' objects}
#         1    0.000    0.000   25.164   25.164 <string>:1(<module>)
#         1    0.000    0.000    0.001    0.001 managers.py:2008(_form_blocks)
#         4    0.000    0.000    0.002    0.000 __init__.py:1077(flush)
#         4    0.000    0.000    0.002    0.001 __init__.py:1600(_log)
#        16    0.000    0.000    0.000    0.000 {built-in method numpy.asarray}
#     23/22    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#      74/8    0.000    0.000    0.000    0.000 abc.py:121(__subclasscheck__)
#         2    0.000    0.000    0.000    0.000 managers.py:1016(iget)
#         1    0.000    0.000    0.003    0.003 <frozen importlib._bootstrap>:987(_find_and_load_unlocked)
#         3    0.000    0.000    0.000    0.000 {pandas._libs.lib.infer_datetimelike_array}
#         9    0.000    0.000    0.002    0.000 <frozen importlib._bootstrap_external>:140(_path_stat)
#        10    0.000    0.000    0.000    0.000 managers.py:1848(internal_values)
#        13    0.000    0.000    0.000    0.000 base.py:7082(maybe_extract_name)
#         1    0.000    0.000    0.008    0.008 generic.py:6299(fillna)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:71(__init__)
#         1    0.000    0.000    0.000    0.000 {built-in method pandas._libs.lib.is_datetime_array}
#         5    0.000    0.000    0.000    0.000 inference.py:262(is_dict_like)
#        45    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:244(_verbose_message)
#        78    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#        19    0.000    0.000    0.000    0.000 threading.py:1095(_wait_for_tstate_lock)
#        13    0.000    0.000    0.000    0.000 common.py:1240(is_float_dtype)
#         7    0.000    0.000    0.000    0.000 blocks.py:1989(get_block_type)
#         1    0.000    0.000    0.008    0.008 blocks.py:448(fillna)
#         9    0.000    0.000    0.000    0.000 flags.py:47(__init__)
#         3    0.000    0.000    0.000    0.000 base.py:7106(_maybe_cast_data_without_dtype)
#         3    0.000    0.000    0.000    0.000 cast.py:1466(maybe_infer_to_datetimelike)
#         1    0.000    0.000    0.000    0.000 base.py:845(_engine)
#         9    0.000    0.000    0.001    0.000 base.py:6987(ensure_index)
#         1    0.000    0.000    0.000    0.000 readers.py:515(_validate_names)
#        10    0.000    0.000    0.000    0.000 series.py:590(name)
#         2    0.000    0.000    0.003    0.001 frame.py:587(__init__)
#         7    0.000    0.000    0.000    0.000 series.py:640(name)
#         6    0.000    0.000    0.000    0.000 common.py:229(asarray_tuplesafe)
#        15    0.000    0.000    0.000    0.000 iostream.py:97(_event_pipe)
#         1    0.000    0.000    0.000    0.000 {built-in method pandas._libs.missing.isnaobj}
#         5    0.000    0.000    0.000    0.000 base.py:654(_simple_new)
#        24    0.000    0.000    0.000    0.000 inference.py:321(is_hashable)
#         1    0.000    0.000    0.000    0.000 numeric.py:133(__new__)
#         9    0.000    0.000    0.000    0.000 {built-in method _abc._abc_instancecheck}
#         3    0.000    0.000    0.000    0.000 re.py:288(_compile)
#         1    0.000    0.000    0.001    0.001 managers.py:1937(create_block_manager_from_column_arrays)
#         5    0.000    0.000    0.000    0.000 config.py:109(_get_single_key)
#         6    0.000    0.000    0.000    0.000 common.py:1274(is_bool_dtype)
#       2/1    0.000    0.000    0.000    0.000 sre_parse.py:174(getwidth)
#         4    0.000    0.000    0.000    0.000 managers.py:1731(from_array)
#         4    0.000    0.000    0.002    0.001 __init__.py:1680(callHandlers)
#         9    0.000    0.000    0.000    0.000 common.py:680(is_integer_dtype)
#         3    0.000    0.000    0.000    0.000 base_parser.py:1289(_is_potential_multi_index)
#         2    0.000    0.000    0.007    0.004 missing.py:149(_isna)
#         4    0.000    0.000    0.002    0.001 __init__.py:1088(emit)
#         4    0.000    0.000    0.002    0.001 __init__.py:955(handle)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:169(__enter__)
#         4    0.000    0.000    0.000    0.000 ntpath.py:44(normcase)
#        24    0.000    0.000    0.000    0.000 sre_parse.py:233(__next)
#         1    0.000    0.000    0.001    0.001 readers.py:935(close)
#         4    0.000    0.000    0.000    0.000 genericpath.py:121(_splitext)
#         3    0.000    0.000    0.000    0.000 warnings.py:130(filterwarnings)
#         3    0.000    0.000    0.000    0.000 warnings.py:181(_add_filter)
#        47    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#         1    0.000    0.000    0.008    0.008 managers.py:253(apply)
#        26    0.000    0.000    0.000    0.000 {built-in method nt.getpid}
#         4    0.000    0.000    0.003    0.001 <__array_function__ internals>:177(concatenate)
#         2    0.000    0.000    0.000    0.000 blocks.py:1916(convert)
#         1    0.000    0.000    0.000    0.000 {built-in method _imp.is_builtin}
#         3    0.000    0.000    0.000    0.000 cast.py:1960(construct_1d_object_array_from_listlike)
#         2    0.000    0.000    0.000    0.000 frame.py:3411(_ixs)
#         8    0.000    0.000    0.000    0.000 typing.py:986(__setattr__)
#         1    0.000    0.000    0.000    0.000 parse.py:437(urlsplit)
#         1    0.000    0.000    0.000    0.000 {method '_rebuild_blknos_and_blklocs' of 'pandas._libs.internals.BlockManager' objects}
#         5    0.000    0.000    0.000    0.000 config.py:589(_get_root)
#         1    0.000    0.000    0.002    0.002 <frozen importlib._bootstrap_external>:1431(find_spec)
#         1    0.000    0.000    0.000    0.000 putmask.py:27(putmask_inplace)
#         1    0.000    0.000    0.000    0.000 common.py:254(_get_filepath_or_buffer)
#         1    0.000    0.000    0.001    0.001 base.py:5092(append)
#        10    0.000    0.000    0.000    0.000 config.py:603(_get_deprecated_option)
#         6    0.000    0.000    0.000    0.000 managers.py:1700(__init__)
#         4    0.000    0.000    0.000    0.000 __init__.py:665(format)
#         5    0.000    0.000    0.000    0.000 config.py:127(_get_option)
#         9    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:67(_relax_case)
#         1    0.000    0.000    0.000    0.000 __init__.py:71(search_function)
#         1    0.000    0.000    0.000    0.000 numeric.py:139(_ensure_array)
#         6    0.000    0.000    0.000    0.000 blocks.py:1960(maybe_coerce_values)
#         1    0.000    0.000    0.001    0.001 series.py:1355(reset_index)
#         8    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(copyto)
#         6    0.000    0.000    0.000    0.000 blocks.py:2055(check_ndim)
#        13    0.000    0.000    0.000    0.000 construction.py:438(ensure_wrapped_if_datetimelike)
#         4    0.000    0.000    0.000    0.000 threading.py:267(__exit__)
#         1    0.000    0.000    0.000    0.000 typing.py:306(inner)
#        10    0.000    0.000    0.000    0.000 common.py:161(is_object_dtype)
#         2    0.000    0.000    0.000    0.000 range.py:167(_simple_new)
#         1    0.000    0.000    0.000    0.000 blocks.py:506(split_and_operate)
#        12    0.000    0.000    0.000    0.000 {built-in method time.time}
#         1    0.000    0.000    0.003    0.003 <frozen importlib._bootstrap>:1038(_gcd_import)
#         1    0.000    0.000    0.000    0.000 base_parser.py:176(_validate_parse_dates_presence)
#         7    0.000    0.000    0.000    0.000 common.py:1747(pandas_dtype)
#         1    0.000    0.000    0.000    0.000 range.py:112(__new__)
#         9    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_scalar}
#         4    0.000    0.000    0.000    0.000 __init__.py:1585(makeRecord)
#         4    0.000    0.000    0.000    0.000 __init__.py:1724(isEnabledFor)
#         1    0.000    0.000    0.000    0.000 typing.py:146(_type_check)
#        29    0.000    0.000    0.000    0.000 sre_parse.py:164(__getitem__)
#         9    0.000    0.000    0.000    0.000 construction.py:627(_sanitize_ndim)
#         2    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_all_arraylike}
#        11    0.000    0.000    0.000    0.000 construction.py:379(extract_array)
#        12    0.000    0.000    0.000    0.000 common.py:1483(is_ea_or_datetimelike_dtype)
#         1    0.000    0.000    0.000    0.000 series.py:4435(_reduce)
#         1    0.000    0.000    0.000    0.000 base_parser.py:340(_maybe_dedup_names)
#         8    0.000    0.000    0.000    0.000 __init__.py:912(acquire)
#         2    0.000    0.000    0.007    0.004 missing.py:267(_isna_string_dtype)
#         4    0.000    0.000    0.000    0.000 common.py:497(is_categorical_dtype)
#         2    0.000    0.000    0.000    0.000 inference.py:98(is_file_like)
#         7    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1053(_handle_fromlist)
#         3    0.000    0.000    0.000    0.000 warnings.py:458(__enter__)
#         8    0.000    0.000    0.000    0.000 common.py:1721(validate_all_hashable)
#         3    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#         6    0.000    0.000    0.000    0.000 construction.py:802(is_empty_data)
#         1    0.000    0.000    0.000    0.000 generic.py:4719(reindex)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:746(find_spec)
#        15    0.000    0.000    0.000    0.000 common.py:155(<lambda>)
#        44    0.000    0.000    0.000    0.000 _collections_abc.py:409(__subclasshook__)
#        22    0.000    0.000    0.000    0.000 sre_parse.py:172(append)
#         2    0.000    0.000    0.000    0.000 cast.py:1304(soft_convert_objects)
#        12    0.000    0.000    0.000    0.000 _validators.py:218(validate_bool_kwarg)
#         1    0.000    0.000    0.000    0.000 sre_compile.py:759(compile)
#         2    0.000    0.000    0.000    0.000 _ufunc_config.py:32(seterr)
#         1    0.000    0.000    0.001    0.001 blocks.py:638(copy)
#         1    0.000    0.000    0.000    0.000 common.py:103(close)
#         2    0.000    0.000    0.000    0.000 {method 'any' of 'numpy.ndarray' objects}
#         5    0.000    0.000    0.000    0.000 series.py:542(_set_axis)
#         7    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_integer}
#         4    0.000    0.000    0.000    0.000 ntpath.py:203(splitext)
#        23    0.000    0.000    0.000    0.000 common.py:147(<lambda>)
#         6    0.000    0.000    0.000    0.000 flags.py:83(allows_duplicate_labels)
#         1    0.000    0.000    0.000    0.000 codecs.py:94(__new__)
#         2    0.000    0.000    0.000    0.000 frame.py:3923(_get_item_cache)
#         1    0.000    0.000    0.002    0.002 concat.py:143(concat)
#         1    0.000    0.000    0.000    0.000 readers.py:1606(_extract_dialect)
#        28    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#        10    0.000    0.000    0.000    0.000 {method 'rpartition' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 typing.py:1016(__init__)
#         4    0.000    0.000    0.000    0.000 threading.py:538(__init__)
#         4    0.000    0.000    0.002    0.001 __init__.py:1626(handle)
#         2    0.000    0.000    0.000    0.000 frame.py:3906(_box_col_values)
#        22    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#         5    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 nanops.py:488(nanany)
#         1    0.000    0.000    0.000    0.000 c_parser_wrapper.py:194(_set_noconvert_columns)
#        23    0.000    0.000    0.000    0.000 sre_parse.py:254(get)
#         1    0.000    0.000    0.000    0.000 base.py:1733(set_names)
#        23    0.000    0.000    0.000    0.000 common.py:145(classes)
#         5    0.000    0.000    0.000    0.000 generic.py:5561(__getattr__)
#         1    0.000    0.000    0.000    0.000 generic.py:10393(_logical_func)
#        10    0.000    0.000    0.000    0.000 series.py:687(_values)
#         1    0.000    0.000    0.000    0.000 nanops.py:257(_get_values)
#         5    0.000    0.000    0.000    0.000 config.py:255(__call__)
#        16    0.000    0.000    0.000    0.000 common.py:1740(<genexpr>)
#         4    0.000    0.000    0.000    0.000 base.py:286(is_dtype)
#        15    0.000    0.000    0.000    0.000 inference.py:288(<genexpr>)
#         3    0.000    0.000    0.000    0.000 base.py:554(_dtype_to_subclass)
#        15    0.000    0.000    0.000    0.000 base.py:4820(_values)
#         1    0.000    0.000    0.000    0.000 __init__.py:43(normalize_encoding)
#         1    0.000    0.000    0.000    0.000 sre_compile.py:536(_compile_info)
#         4    0.000    0.000    0.000    0.000 base.py:5023(__getitem__)
#         1    0.000    0.000    0.000    0.000 managers.py:1844(external_values)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:826(find_spec)
#         8    0.000    0.000    0.000    0.000 threading.py:1423(current_thread)
#         4    0.000    0.000    0.000    0.000 __init__.py:431(_format)
#         1    0.000    0.000    0.000    0.000 missing.py:494(_array_equivalent_object)
#         1    0.000    0.000    0.000    0.000 common.py:500(infer_compression)
#         1    0.000    0.000    0.000    0.000 parse.py:372(urlparse)
#         1    0.000    0.000    0.000    0.000 _validators.py:354(validate_fillna_kwargs)
#         1    0.000    0.000    0.000    0.000 _asarray.py:22(require)
#         2    0.000    0.000    0.000    0.000 blocks.py:2135(ensure_block_shape)
#         1    0.000    0.000    0.000    0.000 typing.py:1137(__getitem__)
#         9    0.000    0.000    0.000    0.000 abc.py:117(__instancecheck__)
#         1    0.000    0.000    0.000    0.000 series.py:463(_init_dict)
#         6    0.000    0.000    0.000    0.000 {method 'remove' of 'list' objects}
#        26    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#         2    0.000    0.000    0.000    0.000 {method 'get_loc' of 'pandas._libs.index.IndexEngine' objects}
#         6    0.000    0.000    0.000    0.000 {pandas._libs.algos.ensure_object}
#        12    0.000    0.000    0.000    0.000 {method 'rfind' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 genericpath.py:27(isfile)
#         4    0.000    0.000    0.000    0.000 __init__.py:160(<lambda>)
#         1    0.000    0.000    0.000    0.000 series.py:4655(reindex)
#        23    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 blocks.py:529(_maybe_downcast)
#         8    0.000    0.000    0.000    0.000 __init__.py:919(release)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.__import__}
#         5    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:893(__enter__)
#         1    0.000    0.000    0.000    0.000 sre_parse.py:939(parse)
#         9    0.000    0.000    0.000    0.000 construction.py:664(_sanitize_str_dtypes)
#         1    0.000    0.000    0.000    0.000 base.py:5178(equals)
#         2    0.000    0.000    0.000    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#         7    0.000    0.000    0.000    0.000 {built-in method _imp.acquire_lock}
#        15    0.000    0.000    0.000    0.000 common.py:150(classes_and_not_datetimelike)
#         1    0.000    0.000    0.000    0.000 ntpath.py:77(join)
#         1    0.000    0.000    0.000    0.000 gbk.py:30(getregentry)
#         4    0.000    0.000    0.000    0.000 enum.py:801(value)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.sorted}
#         5    0.000    0.000    0.000    0.000 config.py:571(_select_options)
#        10    0.000    0.000    0.000    0.000 common.py:1416(is_1d_only_ea_dtype)
#         1    0.000    0.000    0.000    0.000 range.py:189(_data)
#         1    0.000    0.000    0.001    0.001 concat.py:685(_concat_indexes)
#         1    0.000    0.000    0.000    0.000 construction.py:596(_homogenize)
#        19    0.000    0.000    0.000    0.000 threading.py:546(is_set)
#         1    0.000    0.000    0.000    0.000 blocks.py:135(newfunc)
#         1    0.000    0.000    0.003    0.003 common.py:1133(_get_binary_io_classes)
#         1    0.000    0.000    0.000    0.000 {pandas._libs.lib.array_equivalent_object}
#        25    0.000    0.000    0.000    0.000 {built-in method nt.fspath}
#         6    0.000    0.000    0.000    0.000 common.py:552(require_length_match)
#         8    0.000    0.000    0.000    0.000 common.py:1552(get_dtype)
#         2    0.000    0.000    0.000    0.000 base.py:3577(get_loc)
#         4    0.000    0.000    0.000    0.000 {built-in method numpy.array}
#        14    0.000    0.000    0.000    0.000 {built-in method _thread.get_ident}
#         3    0.000    0.000    0.000    0.000 warnings.py:477(__exit__)
#         2    0.000    0.000    0.007    0.004 missing.py:226(_isna_array)
#        11    0.000    0.000    0.000    0.000 base.py:884(__len__)
#         2    0.000    0.000    0.000    0.000 c_parser_wrapper.py:358(<setcomp>)
#         3    0.000    0.000    0.000    0.000 ntpath.py:289(expanduser)
#         8    0.000    0.000    0.000    0.000 typing.py:935(_is_dunder)
#         4    0.000    0.000    0.000    0.000 __init__.py:932(format)
#         4    0.000    0.000    0.000    0.000 __init__.py:423(usesTime)
#         2    0.000    0.000    0.000    0.000 generic.py:5632(_protect_consolidate)
#         4    0.000    0.000    0.000    0.000 threading.py:276(_acquire_restore)
#         2    0.000    0.000    0.000    0.000 _ufunc_config.py:131(geterr)
#         5    0.000    0.000    0.000    0.000 config.py:642(_warn_if_deprecated)
#         1    0.000    0.000    0.000    0.000 readers.py:1007(_check_file_or_buffer)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:968(_sanity_check)
#         2    0.000    0.000    0.000    0.000 _collections_abc.py:78(_check_methods)
#         1    0.000    0.000    0.000    0.000 base_parser.py:610(_set_noconvert_dtype_columns)
#        10    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x00007FFB5F539920}
#         4    0.000    0.000    0.000    0.000 types.py:176(__get__)
#         7    0.000    0.000    0.000    0.000 base.py:834(_reset_identity)
#         1    0.000    0.000    0.000    0.000 base.py:1704(_set_names)
#         3    0.000    0.000    0.000    0.000 generic.py:441(_validate_dtype)
#         4    0.000    0.000    0.000    0.000 __init__.py:643(usesTime)
#         2    0.000    0.000    0.000    0.000 common.py:198(stringify_path)
#         3    0.000    0.000    0.000    0.000 warnings.py:437(__init__)
#         3    0.000    0.000    0.000    0.000 common.py:158(_expand_user)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:165(__init__)
#         8    0.000    0.000    0.000    0.000 __init__.py:806(filter)
#         1    0.000    0.000    0.000    0.000 base_parser.py:1318(_validate_parse_dates_arg)
#         5    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:897(__exit__)
#         4    0.000    0.000    0.000    0.000 ntpath.py:214(basename)
#         1    0.000    0.000    0.000    0.000 sre_parse.py:435(_parse_sub)
#         9    0.000    0.000    0.000    0.000 construction.py:684(_maybe_repeat)
#         1    0.000    0.000    0.000    0.000 construction.py:822(create_series_with_explicit_dtype)
#         1    0.000    0.000    0.000    0.000 base.py:2603(_is_all_dates)
#         1    0.000    0.000    0.008    0.008 frame.py:5209(fillna)
#         1    0.000    0.000    0.001    0.001 construction.py:102(arrays_to_mgr)
#         1    0.000    0.000    0.000    0.000 readers.py:1353(_clean_na_values)
#         1    0.000    0.000    0.000    0.000 _dtype.py:328(_name_get)
#         1    0.000    0.000    0.001    0.001 concat.py:627(_get_concat_axis)
#         4    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 __init__.py:219(_acquireLock)
#         6    0.000    0.000    0.000    0.000 common.py:160(cast_scalar_indexer)
#         2    0.000    0.000    0.000    0.000 c_parser_wrapper.py:356(<listcomp>)
#        19    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#        22    0.000    0.000    0.000    0.000 {built-in method builtins.ord}
#        18    0.000    0.000    0.000    0.000 typing.py:1736(cast)
#         4    0.000    0.000    0.000    0.000 __init__.py:119(getLevelName)
#         1    0.000    0.000    0.000    0.000 __init__.py:24(_module_matches_namespace)
#         1    0.000    0.000    0.001    0.001 c_parser_wrapper.py:187(close)
#         4    0.000    0.000    0.000    0.000 threading.py:264(__enter__)
#         1    0.000    0.000    0.000    0.000 common.py:581(is_dtype_equal)
#         1    0.000    0.000    0.000    0.000 {built-in method _imp.is_frozen}
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:125(release)
#         2    0.000    0.000    0.000    0.000 base.py:465(find)
#         7    0.000    0.000    0.000    0.000 range.py:909(__len__)
#         3    0.000    0.000    0.000    0.000 base.py:45(__len__)
#         9    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#         7    0.000    0.000    0.000    0.000 generic.py:328(attrs)
#         1    0.000    0.000    0.000    0.000 base.py:53(shape)
#         1    0.000    0.000    0.008    0.008 managers.py:413(fillna)
#         2    0.000    0.000    0.000    0.000 {pandas._libs.lib.item_from_zerodim}
#        21    0.000    0.000    0.000    0.000 {built-in method _sre.unicode_iscased}
#         1    0.000    0.000    0.000    0.000 enum.py:986(__and__)
#         2    0.000    0.000    0.000    0.000 _methods.py:54(_any)
#         1    0.000    0.000    0.000    0.000 putmask.py:152(validate_putmask)
#         2    0.000    0.000    0.000    0.000 generic.py:5650(f)
#         2    0.000    0.000    0.000    0.000 generic.py:5646(_consolidate_inplace)
#         1    0.000    0.000    0.000    0.000 series.py:5276(isna)
#        14    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_bool}
#         4    0.000    0.000    0.000    0.000 __init__.py:359(getMessage)
#         1    0.000    0.000    0.000    0.000 _asarray.py:111(<setcomp>)
#         3    0.000    0.000    0.000    0.000 common.py:786(is_unsigned_integer_dtype)
#         1    0.000    0.000    0.000    0.000 base.py:744(__iter__)
#         4    0.000    0.000    0.000    0.000 generic.py:546(_get_axis_number)
#         1    0.000    0.000    0.001    0.001 concat.py:612(<listcomp>)
#         2    0.000    0.000    0.000    0.000 blocks.py:252(make_block)
#         1    0.000    0.000    0.000    0.000 managers.py:973(from_blocks)
#         1    0.000    0.000    0.000    0.000 typing.py:1146(copy_with)
#         1    0.000    0.000    0.000    0.000 missing.py:390(array_equivalent)
#         1    0.000    0.000    0.000    0.000 base.py:1844(rename)
#         2    0.000    0.000    0.000    0.000 base.py:6284(_maybe_cast_indexer)
#         1    0.000    0.000    0.000    0.000 generic.py:7228(isna)
#         2    0.000    0.000    0.000    0.000 c_parser_wrapper.py:360(<setcomp>)
#         4    0.000    0.000    0.000    0.000 __init__.py:438(format)
#         2    0.000    0.000    0.000    0.000 indexing.py:2481(check_deprecated_indexers)
#         6    0.000    0.000    0.000    0.000 base_parser.py:1314(<genexpr>)
#         9    0.000    0.000    0.000    0.000 {method 'lower' of 'str' objects}
#         5    0.000    0.000    0.000    0.000 ntpath.py:34(_get_bothseps)
#         1    0.000    0.000    0.000    0.000 blocks.py:178(_can_hold_na)
#         2    0.000    0.000    0.000    0.000 managers.py:156(blknos)
#         1    0.000    0.000    0.000    0.000 base_parser.py:812(_do_date_conversions)
#         1    0.000    0.000    0.000    0.000 {built-in method sys.getfilesystemencoding}
#         2    0.000    0.000    0.000    0.000 generic.py:4952(<genexpr>)
#         1    0.000    0.000    0.000    0.000 api.py:322(default_index)
#         1    0.000    0.000    0.000    0.000 concat.py:455(<listcomp>)
#         1    0.000    0.000    0.001    0.001 readers.py:1289(__exit__)
#         2    0.000    0.000    0.000    0.000 enum.py:359(__call__)
#         2    0.000    0.000    0.007    0.004 missing.py:66(isna)
#         2    0.000    0.000    0.000    0.000 base.py:4973(__contains__)
#         1    0.000    0.000    0.000    0.000 base.py:5117(<setcomp>)
#         1    0.000    0.000    0.001    0.001 concat.py:610(_get_new_axes)
#         1    0.000    0.000    0.000    0.000 common.py:130(is_url)
#         1    0.000    0.000    0.000    0.000 {built-in method _codecs.lookup}
#         5    0.000    0.000    0.000    0.000 {method 'find' of 'str' objects}
#         4    0.000    0.000    0.000    0.000 threading.py:279(_is_owned)
#         4    0.000    0.000    0.000    0.000 threading.py:1122(name)
#         1    0.000    0.000    0.000    0.000 cast.py:2110(_validate_numeric_casting)
#         1    0.000    0.000    0.000    0.000 common.py:94(consensus_name_attr)
#         1    0.000    0.000    0.000    0.000 base.py:5265(identical)
#         1    0.000    0.000    0.000    0.000 blocks.py:541(<listcomp>)
#         2    0.000    0.000    0.000    0.000 blocks.py:2119(extend_blocks)
#         1    0.000    0.000    0.000    0.000 common.py:242(is_fsspec_url)
#         1    0.000    0.000    0.000    0.000 base_parser.py:269(_extract_multi_indexer_columns)
#         1    0.000    0.000    0.000    0.000 sre_compile.py:598(_code)
#         2    0.000    0.000    0.000    0.000 parse.py:114(_coerce_args)
#         2    0.000    0.000    0.000    0.000 managers.py:1665(is_consolidated)
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.any}
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:357(__init__)
#         1    0.000    0.000    0.000    0.000 sre_parse.py:224(__init__)
#        13    0.000    0.000    0.000    0.000 generic.py:349(flags)
#         1    0.000    0.000    0.000    0.000 generic.py:514(_construct_axes_from_arguments)
#         1    0.000    0.000    0.000    0.000 generic.py:10451(any)
#         6    0.000    0.000    0.000    0.000 managers.py:1792(_block)
#         2    0.000    0.000    0.000    0.000 {built-in method numpy.seterrobj}
#         4    0.000    0.000    0.000    0.000 {built-in method sys._getframe}
#         4    0.000    0.000    0.000    0.000 threading.py:273(_release_save)
#         8    0.000    0.000    0.000    0.000 multiarray.py:1071(copyto)
#         1    0.000    0.000    0.000    0.000 base.py:2596(inferred_type)
#         7    0.000    0.000    0.000    0.000 flags.py:51(allows_duplicate_labels)
#         3    0.000    0.000    0.000    0.000 generic.py:5554(<genexpr>)
#         2    0.000    0.000    0.000    0.000 managers.py:618(consolidate)
#         2    0.000    0.000    0.000    0.000 managers.py:1992(_grouping_func)
#         2    0.000    0.000    0.000    0.000 series.py:1238(_set_as_cached)
#         1    0.000    0.000    0.000    0.000 typing.py:1153(__subclasscheck__)
#         5    0.000    0.000    0.000    0.000 config.py:630(_translate_key)
#         3    0.000    0.000    0.000    0.000 common.py:732(is_signed_integer_dtype)
#         1    0.000    0.000    0.000    0.000 generic.py:560(_get_axis)
#         1    0.000    0.000    0.000    0.000 base_parser.py:383(_make_index)
#         3    0.000    0.000    0.000    0.000 re.py:249(compile)
#         8    0.000    0.000    0.000    0.000 threading.py:1138(ident)
#         4    0.000    0.000    0.000    0.000 __init__.py:649(formatMessage)
#         1    0.000    0.000    0.000    0.000 common.py:177(validate_header_arg)
#        19    0.000    0.000    0.000    0.000 {built-in method _sre.unicode_tolower}
#         2    0.000    0.000    0.000    0.000 common.py:115(ensure_python_int)
#         1    0.000    0.000    0.000    0.000 base.py:785(_view)
#         2    0.000    0.000    0.000    0.000 base.py:2344(is_floating)
#         1    0.000    0.000    0.000    0.000 blocks.py:606(_can_hold_element)
#         9    0.000    0.000    0.000    0.000 {method 'release' of '_thread.RLock' objects}
#         2    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#         4    0.000    0.000    0.000    0.000 multiarray.py:148(concatenate)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(putmask)
#         1    0.000    0.000    0.000    0.000 range.py:893(<listcomp>)
#         1    0.000    0.000    0.000    0.000 <string>:2(__init__)
#         6    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         3    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 typing.py:1142(<genexpr>)
#         1    0.000    0.000    0.000    0.000 cast.py:2147(can_hold_element)
#         1    0.000    0.000    0.000    0.000 construction.py:494(<listcomp>)
#         4    0.000    0.000    0.000    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#         4    0.000    0.000    0.000    0.000 sre_parse.py:160(__len__)
#         1    0.000    0.000    0.000    0.000 typing.py:993(__instancecheck__)
#         1    0.000    0.000    0.000    0.000 common.py:287(maybe_iterable_to_list)
#         2    0.000    0.000    0.000    0.000 base.py:315(shape)
#         2    0.000    0.000    0.000    0.000 blocks.py:358(iget)
#         1    0.000    0.000    0.000    0.000 readers.py:1704(_validate_skipfooter)
#         4    0.000    0.000    0.000    0.000 {built-in method numpy.geterrobj}
#         2    0.000    0.000    0.000    0.000 sre_parse.py:111(__init__)
#         1    0.000    0.000    0.000    0.000 typing.py:947(__init__)
#         1    0.000    0.000    0.000    0.000 copy.py:66(copy)
#         1    0.000    0.000    0.000    0.000 tempfile.py:297(gettempdir)
#         2    0.000    0.000    0.000    0.000 concat.py:95(is_nonempty)
#         1    0.000    0.000    0.000    0.000 cast.py:2088(convert_scalar_for_putitemlike)
#         1    0.000    0.000    0.000    0.000 common.py:201(all_none)
#         1    0.000    0.000    0.000    0.000 _ufunc_config.py:429(__enter__)
#         2    0.000    0.000    0.000    0.000 common.py:1148(needs_i8_conversion)
#         1    0.000    0.000    0.000    0.000 putmask.py:166(extract_bool_array)
#         1    0.000    0.000    0.000    0.000 blocks.py:2239(external_values)
#         1    0.000    0.000    0.000    0.000 series.py:645(values)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:173(__exit__)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:198(cb)
#         2    0.000    0.000    0.000    0.000 enum.py:678(__new__)
#         1    0.000    0.000    0.000    0.000 sre_compile.py:461(_get_literal_prefix)
#         1    0.000    0.000    0.000    0.000 sre_parse.py:923(fix_flags)
#         1    0.000    0.000    0.000    0.000 concat.py:557(<listcomp>)
#         1    0.000    0.000    0.000    0.000 base_parser.py:1154(_process_date_conversion)
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.sum}
#         1    0.000    0.000    0.000    0.000 sre_compile.py:423(_simple)
#         2    0.000    0.000    0.000    0.000 common.py:533(is_string_or_object_np_dtype)
#         3    0.000    0.000    0.000    0.000 range.py:859(<genexpr>)
#         1    0.000    0.000    0.000    0.000 managers.py:1673(_consolidate_check)
#         3    0.000    0.000    0.000    0.000 base_parser.py:1340(is_index_col)
#         1    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#         9    0.000    0.000    0.000    0.000 {built-in method _warnings._filters_mutated}
#         1    0.000    0.000    0.000    0.000 typing.py:206(_collect_type_vars)
#         1    0.000    0.000    0.000    0.000 _ufunc_config.py:434(__exit__)
#         1    0.000    0.000    0.000    0.000 numeric.py:199(_ensure_dtype)
#         1    0.000    0.000    0.000    0.000 common.py:1058(_maybe_memory_map)
#         3    0.000    0.000    0.000    0.000 series.py:743(__len__)
#         1    0.000    0.000    0.000    0.000 {built-in method nt.getcwd}
#         2    0.000    0.000    0.000    0.000 sre_parse.py:286(tell)
#         1    0.000    0.000    0.000    0.000 concat.py:106(<listcomp>)
#         2    0.000    0.000    0.000    0.000 common.py:346(apply_if_callable)
#         1    0.000    0.000    0.000    0.000 missing.py:911(clean_reindex_fill_method)
#         1    0.000    0.000    0.000    0.000 __init__.py:57(find_spec)
#         3    0.000    0.000    0.000    0.000 base.py:2624(_is_multi)
#         1    0.000    0.000    0.000    0.000 generic.py:10873(any)
#         1    0.000    0.000    0.000    0.000 blocks.py:209(external_values)
#         6    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_iterator}
#         1    0.000    0.000    0.000    0.000 os.py:816(fsdecode)
#         3    0.000    0.000    0.000    0.000 concat.py:112(<genexpr>)
#         1    0.000    0.000    0.000    0.000 nanops.py:346(_na_ok_dtype)
#         6    0.000    0.000    0.000    0.000 base.py:326(ndim)
#         1    0.000    0.000    0.000    0.000 base.py:4846(_get_engine_target)
#         2    0.000    0.000    0.000    0.000 blocks.py:354(dtype)
#         3    0.000    0.000    0.000    0.000 base.py:55(<genexpr>)
#         1    0.000    0.000    0.000    0.000 {built-in method _sre.compile}
#         7    0.000    0.000    0.000    0.000 {built-in method _imp.release_lock}
#         1    0.000    0.000    0.000    0.000 _collections_abc.py:381(__subclasshook__)
#         2    0.000    0.000    0.000    0.000 sre_compile.py:453(_get_iscased)
#         1    0.000    0.000    0.000    0.000 __init__.py:228(_releaseLock)
#         1    0.000    0.000    0.000    0.000 base.py:803(is_)
#         3    0.000    0.000    0.000    0.000 series.py:523(_constructor)
#         6    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_float}
#         4    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#         1    0.000    0.000    0.000    0.000 os.py:1079(__subclasshook__)
#         1    0.000    0.000    0.000    0.000 sre_compile.py:492(_get_charset_prefix)
#         1    0.000    0.000    0.000    0.000 sre_parse.py:76(__init__)
#         1    0.000    0.000    0.000    0.000 concat.py:111(<setcomp>)
#         3    0.000    0.000    0.000    0.000 concat.py:118(<genexpr>)
#         3    0.000    0.000    0.000    0.000 base.py:540(_ensure_array)
#         5    0.000    0.000    0.000    0.000 base.py:1650(name)
#         2    0.000    0.000    0.000    0.000 base_parser.py:371(_maybe_make_multi_index_columns)
#         1    0.000    0.000    0.000    0.000 base_parser.py:832(_check_data_length)
#         3    0.000    0.000    0.000    0.000 {method 'insert' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 typing.py:1022(<genexpr>)
#         1    0.000    0.000    0.000    0.000 cast.py:1711(sanitize_to_nanoseconds)
#         1    0.000    0.000    0.000    0.000 nanops.py:213(_maybe_get_mask)
#         2    0.000    0.000    0.000    0.000 base.py:5278(<genexpr>)
#         2    0.000    0.000    0.000    0.000 generic.py:5549(<genexpr>)
#         1    0.000    0.000    0.000    0.000 managers.py:1683(_consolidate_inplace)
#         1    0.000    0.000    0.000    0.000 common.py:465(get_compression_method)
#         1    0.000    0.000    0.000    0.000 c_parser_wrapper.py:205(<dictcomp>)
#         2    0.000    0.000    0.000    0.000 sre_compile.py:595(isstring)
#         1    0.000    0.000    0.000    0.000 concat.py:117(<setcomp>)
#         1    0.000    0.000    0.000    0.000 concat.py:634(<listcomp>)
#         1    0.000    0.000    0.000    0.000 concat.py:678(_maybe_check_integrity)
#         1    0.000    0.000    0.000    0.000 construction.py:233(mgr_to_mgr)
#         1    0.000    0.000    0.000    0.000 base_parser.py:1062(_make_date_converter)
#         1    0.000    0.000    0.000    0.000 c_parser_wrapper.py:308(<dictcomp>)
#         3    0.000    0.000    0.000    0.000 {method 'isalnum' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 typing.py:137(_type_convert)
#         2    0.000    0.000    0.000    0.000 sre_parse.py:81(groups)
#         1    0.000    0.000    0.000    0.000 _ufunc_config.py:425(__init__)
#         3    0.000    0.000    0.000    0.000 base.py:937(dtype)
#         1    0.000    0.000    0.000    0.000 generic.py:543(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 range.py:870(<listcomp>)
#         2    0.000    0.000    0.000    0.000 blocks.py:350(shape)
#         3    0.000    0.000    0.000    0.000 managers.py:222(items)
#         2    0.000    0.000    0.000    0.000 managers.py:919(__init__)
#         4    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 ntpath.py:221(dirname)
#         1    0.000    0.000    0.000    0.000 typing.py:223(_check_generic)
#         3    0.000    0.000    0.000    0.000 common.py:191(<genexpr>)
#         1    0.000    0.000    0.000    0.000 common.py:187(not_none)
#         2    0.000    0.000    0.000    0.000 base.py:518(<genexpr>)
#         2    0.000    0.000    0.000    0.000 numeric.py:188(_validate_dtype)
#         1    0.000    0.000    0.000    0.000 concat.py:604(_get_result_dim)
#         2    0.000    0.000    0.000    0.000 managers.py:172(blklocs)
#         1    0.000    0.000    0.000    0.000 base_parser.py:240(_has_complex_date_col)
#         1    0.000    0.000    0.000    0.000 c_parser_wrapper.py:206(<listcomp>)
#         1    0.000    0.000    0.000    0.000 c_parser_wrapper.py:408(ensure_dtype_objs)
#         2    0.000    0.000    0.000    0.000 sre_parse.py:249(match)
#         1    0.000    0.000    0.000    0.000 six.py:194(find_spec)
#         1    0.000    0.000    0.000    0.000 cast.py:2185(np_can_hold_element)
#         1    0.000    0.000    0.000    0.000 _dtype.py:314(_name_includes_bit_suffix)
#         3    0.000    0.000    0.000    0.000 base.py:229(disallow_kwargs)
#         1    0.000    0.000    0.000    0.000 generic.py:660(ndim)
#         1    0.000    0.000    0.000    0.000 base_parser.py:220(<setcomp>)
#         1    0.000    0.000    0.000    0.000 c_parser_wrapper.py:304(<listcomp>)
#         1    0.000    0.000    0.000    0.000 __init__.py:1710(getEffectiveLevel)
#         1    0.000    0.000    0.000    0.000 <string>:1(<lambda>)
#         2    0.000    0.000    0.000    0.000 common.py:205(<genexpr>)
#         1    0.000    0.000    0.000    0.000 _dtype.py:24(_kind_name)
#         2    0.000    0.000    0.000    0.000 numeric.py:331(_is_all_dates)
#         1    0.000    0.000    0.000    0.000 managers.py:217(is_single_block)
#         1    0.000    0.000    0.000    0.000 base_parser.py:920(_validate_usecols_arg)
#         1    0.000    0.000    0.000    0.000 {built-in method _codecs.lookup_error}
#         3    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 tempfile.py:285(_gettempdir)
#         1    0.000    0.000    0.000    0.000 function.py:49(__call__)
#         1    0.000    0.000    0.000    0.000 range.py:241(start)
#         2    0.000    0.000    0.000    0.000 {method 'pop' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 sre_parse.py:168(__setitem__)
#         1    0.000    0.000    0.000    0.000 __init__.py:1307(disable)
#         1    0.000    0.000    0.000    0.000 frame.py:578(_constructor)
#         1    0.000    0.000    0.000    0.000 range.py:264(stop)
#         1    0.000    0.000    0.000    0.000 {built-in method _stat.S_ISREG}
#         1    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         3    0.000    0.000    0.000    0.000 {method 'isascii' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 copy.py:107(_copy_immutable)
#         2    0.000    0.000    0.000    0.000 parse.py:103(_noop)
#         1    0.000    0.000    0.000    0.000 parse.py:419(_checknetloc)
#         1    0.000    0.000    0.000    0.000 missing.py:107(clean_fill_method)
#         1    0.000    0.000    0.000    0.000 multiarray.py:1106(putmask)
#         2    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'reverse' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'partition' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 nanops.py:191(_get_fill_value)
#         1    0.000    0.000    0.000    0.000 managers.py:282(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 readers.py:1286(__enter__)
#         1    0.000    0.000    0.000    0.000 range.py:287(step)
#         1    0.000    0.000    0.000    0.000 base.py:150(is_consolidated)
#         1    0.000    0.000    0.000    0.000 base_parser.py:232(<listcomp>)

# %% [markdown]
# rener_research_result函数为查询函数
#
# 将展示根据关键词/布尔查询语句检索到的条目数、检索时间等信息，可选择是否打印检索结果
#
# q: 查询query，为字符串类型，可通过and、or自定义布尔查询条件
#
# result_print: 是否打印结果

# %%
# 布尔查询 + 打印结果
q = '(左肺 or 右肺) and 间质性'
a = mr.rener_research_result(q,result_print=True)
# Out:
# The length of results is  161
# 【search】time cost: 0.012965679168701172 s
#
#
# doc_id:43140, score:4.180014577067371,
# doc:双肺【间质性】渗出改变，注意【间质性】肺炎。
# 【右肺】中、下叶钙化灶。
# 双侧胸膜局限增厚。
#
# doc_id:50439, score:4.095018217420474,
# doc:双肺【间质性】改变，注意【间质性】肺炎。
# 【右肺】中叶少许慢性炎症。
# 左肾占位，建议进一步检查。
#
# doc_id:47773, score:3.87805908934584,
# doc:双肺【间质性】改变并【间质性】炎症。
# 双肺散在少许气肿。
# 【右肺】可见散在多发小结节，建议随诊复查。
# 右侧胸膜增厚钙化。
#
# doc_id:26553, score:3.734103236864826,
# doc:【右肺】上叶占位，性质待定，建议进一步增强检查。
# 双肺胸膜下【间质性】病变，注意【间质性】肺炎。
# 双肺散在小叶中心型及间隔旁型肺气肿。
#
# doc_id:28482, score:3.550150452149468,
# doc:【右肺】下叶炎症。
# 双肺多叶、段【间质性】病变。
#
# doc_id:40433, score:3.550150452149468,
# doc:双肺散在【间质性】炎症。
# 【右肺】上叶泡性气肿。
#
# doc_id:30542, score:3.460990280761105,
# doc:双肺多发【间质性】炎症，请结合临床。
# 【左肺】下叶外侧底段小结节，随诊复查。
#
# doc_id:40464, score:3.4262197580313494,
# doc:双肺多发【间质性】炎症，以【右肺】为著。建议抗炎后复查。
#
# doc_id:49570, score:3.4063078212327875,
# doc:双肺多发【间质性】病变，【左肺】上叶为著。
# 左侧胸腔积液。
# 纵隔间隙淋巴结增大。
#
# doc_id:34156, score:3.3388050622734324,
# doc:双肺多发炎症、部分实变。
# 【右肺】中叶内侧段【间质性】肺气肿。
#
# doc_id:42571, score:3.327033548831792,
# doc:【右肺】胸膜下斑片影，【间质性】改变？
# 【左肺】下叶背段胸膜下小结节，随诊复查。
#
# doc_id:32175, score:3.313968506561074,
# doc:【左肺】上叶前段及【左肺】下叶前内底段炎症，部分实变。
# 双肺胸膜下【间质性】炎症？
# 胰尾部囊肿？
#
# doc_id:36286, score:3.3019679003279636,
# doc:双肺多发【间质性】肺炎。
# 【左肺】上叶尖后段纤维增殖钙化性病变。
# 主动脉壁局部少量钙化。
#
# doc_id:27953, score:3.2768741035600035,
# doc:【左肺】下叶空洞性病变，请结合临床，抗炎治疗后复查。
# 双肺多发【间质性】病变，部分实变。
#
# doc_id:34405, score:3.2557398964025577,
# doc:双肺【间质性】炎症较前同前；【右肺】上叶新增炎症。
# 余所见基本同前。
#
# doc_id:50277, score:3.2119204602362297,
# doc:双肺门区占位，恶性可能大，请结合临床相关检查。
# 双肺多发小结节，不除外转移灶，请密切随诊复查。
# 胸膜下【间质性】病变，注意间质纤维化及【间质性】肺炎。
# 【左肺】下叶散在小叶中心型肺气肿；【右肺】下叶肺大疱。
# 双侧胸腔少量积液。
#
# doc_id:42658, score:3.202621828030732,
# doc:【间质性】肺炎？伴支气管扩张。
# 【右肺】下叶外侧底段结节，炎性可能性大。
#
# doc_id:47095, score:3.1512091995524236,
# doc:【右肺】中叶病变同前。
# 双肺散在【间质性】炎症较前略减少。
# 余所见基本同前。
#
# doc_id:42799, score:3.1113575294695877,
# doc:【左肺】下叶病变较前减小。
# 双肺【间质性】病变及实变较前减轻。
# 双侧胸腔积液较前减少。
# 余所见基本同前。
#
# doc_id:38370, score:3.1113575294695877,
# doc:【左肺】下叶病变较前减小。
# 双肺【间质性】病变及实变基本同前。
# 双侧胸腔积液基本同前。
# 余所见基本同前。
#
# doc_id:51494, score:3.1047199358552,
# doc:【右肺】中叶和双肺下叶【间质性】炎症。
# 【右肺】多发小结节，请结合临床定期复查。
#
# doc_id:35563, score:3.089067477173347,
# doc:【左肺】下叶病变较前略减小。
# 双肺【间质性】病变及实变基本同前。
# 双侧胸腔积液基本同前。
# 余所见基本同前。
#
# doc_id:38491, score:3.0798267348540453,
# doc:双肺背侧【间质性】改变。
# 【右肺】上叶胸膜下小结节，肉芽肿病变？
# 【左肺】上叶前段气肿。
# 胆囊结石。
#
# doc_id:46785, score:3.077112513644048,
# doc:双肺【间质性】肺炎合并间质纤维化。
# 【右肺】中叶支气管轻度扩张。
# 纵隔淋巴结增大。
#
# doc_id:50719, score:3.0064203537295335,
# doc:双肺【间质性】肺炎。
# 【右肺】上叶钙化结节。
# 双侧肋间胸膜增厚。
# 动脉硬化。
# 胆囊结石。
#
# doc_id:49015, score:3.0064203537295335,
# doc:双肺散在结节，炎性可能大，随诊复查。
# 【右肺】下叶【间质性】肺炎
# 双肺散在少许慢性炎症。
#
# doc_id:31341, score:3.0030120558504736,
# doc:【左肺】下叶空洞引流术后，范围较前减小。
# 双肺【间质性】病变密度明显增高。
# 双侧胸腔新增积液。
# 余所见基本同前。
#
# doc_id:46495, score:2.9835726145531307,
# doc:双肺多发【间质性】肺炎。
# 【右肺】上叶结节，炎症可能性大。
# 双侧胸膜增厚，左侧膈胸膜钙化。
#
# doc_id:33940, score:2.961069525747354,
# doc:双肺散在【间质性】炎症和小叶中心型气肿。
# 【右肺】中叶小结节，炎性可能大。
# 双侧胸膜增厚。
#
# doc_id:41048, score:2.9447639583752943,
# doc:双肺【间质性】病变。
# 【左肺】上叶舌段及下叶支气管内少许高密度影，痰栓？
# 双侧胸腔少许积液。
# 纵隔内及【左肺】门多发增大淋巴结影。
#
# doc_id:42517, score:2.9415525984082285,
# doc:双肺散在磨玻璃影及斑条影，注意【间质性】肺病。
# 【左肺】钙化小结节。
# 双侧肋间胸膜局限性增厚。
# 腹部改变请结合相关检查。
#
# doc_id:51603, score:2.9415525984082285,
# doc:双肺【间质性】肺炎伴间质纤维化改变同前。
# 双肺内小结节，炎性？
# 动脉硬化同前。
# 【左肺】动脉增粗。
# 余胸部所见基本同前。
#
# doc_id:49541, score:2.9389033472896666,
# doc:双肺散在【间质性】肺炎。
# 双肺散在间隔旁型肺气肿。
# 双肺胸膜多发增厚。
# 【右肺】上叶钙化结节。
#
# doc_id:32569, score:2.901958398676845,
# doc:双肺多发炎症（【间质性】炎症为主）。
# 注意【左肺】下叶胸膜下线形成。
# 纵隔及双肺门多发稍大淋巴结。
# 双侧胸腔胸膜局限性增厚。
#
# doc_id:47750, score:2.8743522738695604,
# doc:双肺【间质性】改变，双肺少许渗出性炎症及炎性索条。
# 【右肺】下叶局限泡性气肿。
# 双侧胸膜局部增厚。
#
# doc_id:29882, score:2.8743522738695604,
# doc:双肺散在斑片、【右肺】上叶实变，炎症？抗炎后复查。
# 右侧胸腔积液。
# 双肺【间质性】水肿，左心室增大。
#
# doc_id:41794, score:2.8743522738695604,
# doc:双肺【间质性】炎症伴部分间质纤维化较前加重。
# 【右肺】门及纵隔间隙淋巴结较前增大。
# 余所见基本同前。
#
# doc_id:31712, score:2.8743522738695604,
# doc:双肺【间质性】炎症。
# 【右肺】下叶前基底段斑条及结节，建议复查。
# 纵隔内多发增大淋巴结。
# 动脉硬化。
#
# doc_id:46412, score:2.8698788145641903,
# doc:【右肺】上叶及中叶多发钙化及非钙化小结节，炎性？
# 【右肺】多发【间质性】病变。
# 右侧胸膜局部稍增厚。
#
# doc_id:36676, score:2.84452610852686,
# doc:【左肺】【间质性】改变，下叶为著，局部实变。
# 双肺散在小结节，炎性？建议随诊复查。
# 双肺散在慢性炎症。
# 腹部改变请结合相关检查。
#
# doc_id:30764, score:2.832870847532445,
# doc:双肺散在少许慢性炎症，部分为【间质性】。
# 【右肺】下叶前底段小结节，炎性肉芽肿可能性大。
# 胆囊小结石。
#
# doc_id:34075, score:2.7925696728199956,
# doc:【右肺】中叶混合磨玻璃密度结节较前增大，恶性可能性大。
# 双肺【间质性】肺炎较前无明显变化。
# 余所见基本同前。
#
# doc_id:37301, score:2.7925696728199956,
# doc:双肺【间质性】肺水肿。
# 【右肺】尖见模糊小结节，炎性可能大。
# 双侧少量胸腔积液。
# 心脏增大，请结合超声检查。
#
# doc_id:29992, score:2.789322971806549,
# doc:左侧液气胸，【左肺】膨胀不良及炎症。
# 双肺散在小叶中心型及间隔旁型肺气肿。
# 双肺【间质性】改变，双肺下叶为著。
# 左侧第5-9后肋骨折。
#
# doc_id:28414, score:2.78090860008723,
# doc:【左肺】上叶占位，恶性？
# 【左肺】门及纵隔肿大淋巴结。
# 双肺多发炎症，以双肺下叶为著，呈【间质性】改变。
# 双肺多发肺气肿基本同前。
# 余所见基本同前。
#
# doc_id:38066, score:2.772846049838277,
# doc:双肺散在多发【间质性】肺炎并间质纤维化。
# 【右肺】下叶后底段钙化结节。
# 双侧少量胸腔积液。
# 双肺散在肺气肿。
#
# doc_id:27417, score:2.772846049838277,
# doc:双肺【间质性】改变，双肺下叶为著。
# 双肺尖纤维、增殖、钙化病变。
# 【右肺】上叶模糊小结节，炎性？建议随诊复查。
#
# doc_id:51026, score:2.772846049838277,
# doc:【右肺】上叶毁损肺。
# 双肺多发炎症及【间质性】改变基本同前。
# 双肺多发气肿伴肺大疱形成同前。
# 余所见基本同前。
#
# doc_id:37853, score:2.7611309199385174,
# doc:【左肺】上叶新发炎症。
# 余双肺【间质性】肺病未见明显变化。
# 【右肺】下叶上段结节同前；【右肺】下叶胸膜下肺大疱。
# 余所见基本同前。
#
# doc_id:30258, score:2.7536960278651694,
# doc:【左肺】下叶基底段小结节，炎性？请随诊复查。
# 双肺胸膜下【间质性】肺炎。
# 双肺散在气肿。
# 左侧第9-11后肋形态欠规整，请结合临床及病史。
#
# doc_id:29963, score:2.7533990845608654,
# doc:双肺多发【间质性】肺炎。
# 【右肺】中叶外侧段慢性炎症。
# 双侧胸膜多发增厚伴钙化。
# 甲状腺右叶结节，请结合相关检查
#
# doc_id:38171, score:2.7533990845608654,
# doc:双肺散在慢性炎症伴【间质性】改变。
# 【右肺】上叶尖段钙化及少许纤维性病变。
# 动脉硬化。
# 纵隔间隙淋巴结略大。
#
# doc_id:35325, score:2.7533990845608654,
# doc:双肺下叶肺不张、双肺【间质性】肺水肿。
# 双侧少量胸腔积液及叶间积液。
# 【右肺】散在小叶中心型及间隔旁型肺气肿。
#
# doc_id:42549, score:2.7525881702748967,
# doc:【右肺】上叶后段、中叶内侧段及【左肺】上叶前段结节，炎性肉芽肿。
# 双肺下叶慢性炎症，合并【间质性】病变。
# 纵隔淋巴结略肿大。
# 副脾。
#
# doc_id:39581, score:2.742235948913558,
# doc:双侧少量胸腔积液。
# 双肺【间质性】炎症，【左肺】上叶病变较前略吸收。
# 【右肺】中叶胸膜下小结节基本同前。
# 【右肺】下叶局灶泡性气肿。
#
# doc_id:30595, score:2.734222996627953,
# doc:【右肺】下叶胸膜下小结节，注意随诊复查。
# 双肺散在少许慢性炎症，轻度【间质性】改变。
# 左侧胸腔少许积液或胸膜增厚。
#
# doc_id:41976, score:2.734222996627953,
# doc:双肺【间质性】病变较前未见明显变化。
# 【右肺】下叶多发钙化结节同前。
# 纵隔多发肿大淋巴结影同前。
# 余所见基本同前。
#
# doc_id:34067, score:2.7153121655956007,
# doc:双肺散在多发肺炎（注意部分【间质性】炎症）。
# 【右肺】中叶小结节，考虑炎性，建议定期复查。
# 纵隔旁散在间隔旁肺气肿。
#
# doc_id:41672, score:2.6782645593078365,
# doc:【右肺】上叶后段病变较前吸收、减少。
# 双肺散在多发【间质性】肺炎并间质纤维化基本同前，周围渗出稍减少。
# 余所见基本同前。
#
# doc_id:38120, score:2.6782645593078365,
# doc:双肺多叶段【间质性】炎症，伴支气管轻度扩张。
# 双肺散在慢性炎症；【右肺】多发钙化结节。
# 纵隔多发钙化淋巴结。
# 动脉硬化。
#
# doc_id:50996, score:2.6782645593078365,
# doc:双肺多发【间质性】肺炎较前略吸收。
# 【右肺】中叶外侧段慢性炎症同前。
# 双侧胸膜多发增厚伴钙化同前。
# 甲状腺右叶结节同前。
#
# doc_id:48888, score:2.6601172944275926,
# doc:1.双肺【间质性】炎症无明显变化。
# 2.【右肺】中叶不整形小结节病变无明显变化。
# 3.冠脉钙化。
# 4.余所见基本同前。
#
# doc_id:49933, score:2.6601172944275926,
# doc:1.双侧胸腔积液及【右肺】叶间积液，双肺组织膨胀不良或炎症。
# 2.双肺上叶小叶间隔增厚，【间质性】肺水肿。
# 3.冠脉钙化。
#
# doc_id:45875, score:2.6601172944275926,
# doc:双肺散在慢性炎症同前。
#
# 【右肺】中叶及双肺下叶胸膜下区【间质性】病变同前。
#
# 左侧胸腹膜裂孔疝。
# 余胸部所见基本同前。
#
# doc_id:39846, score:2.6591189356728053,
# doc:双肺上叶渗出【间质性】炎症较前略增多，余双肺散在【间质性】炎症较前明显减少。
# 【右肺】上叶尖段钙化、纤维增殖性性病变同前，注意继发性结核（较陈旧）。
# 双肺小叶中心型肺气肿基本同前。
# 左侧胸腔积液较前吸收、减少；右侧胸腔积液较前增多。
# 纵隔内多发增大淋巴结基本同前。
# 心影稍大，主动脉钙化。
# 余胸部所见基本同前。
#
# doc_id:28265, score:2.642214297295828,
# doc:双肺散在多发渗出、炎症及【间质性】改变。
# 双肺野透过度不均，结合临床。
# 双侧胸腔及心包少量积液。
# 【右肺】上叶尖段小气肿。
#
# doc_id:51174, score:2.6358620630729144,
# doc:双肺多叶段炎症及【间质性】改变。
# 【左肺】多发钙化及非钙化结节，必要时定期复查。
# 动脉硬化。
# 双侧甲状腺体积增大。
# 肝内多发钙化灶。
# 食管内多发高密度影。
#
# doc_id:27816, score:2.627005492531712,
# doc:双肺新增多发炎症，以【左肺】下叶为著（注意【间质性】肺炎）。
# 【右肺】上叶尖段泡性气肿同前。
# 【左肺】下叶上段钙化结节。
# 冠脉少许钙化。
# 余胸部所见基本同前。
#
# doc_id:48286, score:2.6198468633489753,
# doc:双肺【间质性】炎症较前无明显变化。
# 【左肺】下叶结节同前。
# 双肺上叶多发间隔旁型气肿同前。
# 双侧腋窝多枚肿大淋巴结，纵隔内多枚稍大淋巴结。
# 余所见基本同前。
#
# doc_id:42893, score:2.6127074536811974,
# doc:双肺【右肺】多发【间质性】病变，双肺多发气肿。
# 双侧胸膜增厚，左侧胸膜钙化。
# 【右肺】上叶前段结节结核球。
# 左侧胸腹膜裂孔疝。
#
# doc_id:37542, score:2.6071216407766875,
# doc:双肺下叶炎症较前增多。
# 双肺胸膜下散在慢性【间质性】炎症无明显变化。
# 【右肺】上叶后段细小结节病变无明显变化。
# 余所见基本同前。
#
# doc_id:42211, score:2.5883932936477234,
# doc:双肺间质纤维化、并【间质性】肺炎。
# 【左肺】钙化及非钙化结节，建议随诊复查。
# 双肺散在多发肺气肿。
# 双侧胸腔积液；叶间裂积液。
# 心影增大，心包积液；冠脉钙化。
#
# doc_id:28369, score:2.572948934463343,
# doc:双肺【间质性】病变较未见明显变化。
# 双肺少许泡性气肿同前。
# 【右肺】中叶钙化灶同前。
# 甲状腺左叶改变，请结合临床。
# 余所见基本同前。
#
# doc_id:34585, score:2.5561963316780623,
# doc:双肺多发【间质性】肺炎较前稍吸收。
# 【右肺】中叶外侧段慢性炎症同前。
# 双侧胸膜多发增厚伴钙化同前。
# 甲状腺右叶结节同前，请结合相关检查
#
# doc_id:40556, score:2.5497328333063956,
# doc:双肺散在囊性病变，符合淋巴细胞性【间质性】肺炎（LIP）。
# 【右肺】中叶内侧段及【左肺】上叶下舌段少许慢性炎症。
# 【左肺】下叶后底段小结节，炎性？
# 左侧肋胸膜局部增厚。
#
# doc_id:26655, score:2.5396604717846114,
# doc:双肺散在渗出病变，结合临床。
# 【右肺】及左下肺小叶间隔增厚，不除外【间质性】肺水肿，请结合临床，必要时复查。
# 双侧胸腔积液。
# 动脉硬化。
#
# doc_id:49789, score:2.5396604717846114,
# doc:双肺【间质性】肺炎。
# 【右肺】下叶后底段局灶实性病变，性质待定。
# 双肺散在小叶中心型及间隔旁型肺气肿。
# 纵隔间隙淋巴结增大。
# 动脉硬化。
#
# doc_id:30657, score:2.5396604717846114,
# doc:双肺下叶少许炎症较前吸收。
# 双肺少许慢性炎症同前。
# 【右肺】中下叶【间质性】病变。
# 甲状腺及肝脏改变，请结合相关检查。
# 余所见基本同前。
#
# doc_id:43491, score:2.527698791809313,
# doc:【左肺】上叶尖后段钙化结节。
# 双肺散在慢性炎症及【间质性】病变；双侧胸膜增厚。
# 双肺上叶多发中心型及间隔旁型肺气肿。
# 纵隔淋巴结肿大。
# 动脉硬化伴腹壁血栓；瓣膜钙化。
#
# doc_id:31689, score:2.512967326887046,
# doc:双肺小叶中心型及间隔旁型肺气肿同前。
# 双肺下叶模糊斑片影同前，考虑【间质性】炎症。
# 【左肺】下叶前底段小结节同前，炎性肉芽肿可能大。
# 腹部改变，请结合临床及腹部相关检查。
#
# doc_id:48176, score:2.491312087370141,
# doc:纵隔及左侧颈部气肿，双肺【间质性】气肿。
# 【右肺】中叶局灶性肺气肿。
# 双肺多发渗出性炎性病变。
# 双侧胸腔积液。
# 双侧甲状腺改变，结合专科检查。
#
# doc_id:29521, score:2.4882102019782057,
# doc:【右肺】中叶、【左肺】上叶舌段及双肺下叶【间质性】肺水肿、渗出性病变，请结合临床。
# 双肺散在小叶中央型、间隔旁型肺气肿。
# 甲状腺及腹部改变，请结合临床及相关检查。
#
# doc_id:41304, score:2.4879978675209173,
# doc:【左肺】上叶炎症较前稍减少。
# 余双肺【间质性】肺病未见明显变化。
# 【右肺】中叶、【左肺】下叶上段结节同前；【右肺】下叶胸膜下肺大疱同前。
# 腹部所见，请结合临床及相关腹部检查。
#
# doc_id:50263, score:2.47560245733698,
# doc:【右肺】上叶前段纤维、钙化性病变同前。
# 双肺散在磨玻璃密度区同前，【间质性】病变不除外。
# 双腋窝及纵隔间隙散在稍大淋巴结同前。
# 余所见基本同前。
#
# doc_id:32780, score:2.459970074363317,
# doc:【右肺】上叶不整形斑片、双肺散在小结节及斑片，性质待定。
# 【右肺】上叶【间质性】水肿。
# 双肺散在炎症。
# 双侧胸腔积液，心包少量积液。
# 冠脉钙化。
#
# doc_id:30634, score:2.444770162210931,
# doc:【右肺】上叶前段占位较前略增大，恶性可能性大；纵隔淋巴结较前增大。
# 双肺少许慢性炎症较前略减少；胸膜下轻度【间质性】改变基本同前。
# 余所见基本同前。
#
# doc_id:48442, score:2.43516969076818,
# doc:【左肺】上叶尖段细小结节，炎性可能大，随诊复查。
# 【左肺】上叶少许慢性炎症，邻近肺组织小叶间隔增厚，【间质性】改变？
# 【右肺】上叶前段泡性气肿，请结合临床。
# 乳腺改变，请结合相关检查。
#
# doc_id:33533, score:2.4146964189855895,
# doc:双肺散在多发渗出、炎症及【间质性】改变较前加重。
# 双肺野透过度不均同前，结合临床。
# 双侧胸腔及心包少量积液同前。
# 【右肺】上叶尖段小气肿较前显示模糊。
#
# doc_id:26455, score:2.4146964189855895,
# doc:双肺多发炎症，【间质性】肺炎可能性大。
# 双肺散在瘢痕性肺气肿。
# 【右肺】上叶后段钙化结节。
# 双侧胸膜局限性增厚。
# 纵隔间隙淋巴结稍大伴钙化。
# 动脉硬化。
#
# doc_id:30295, score:2.411914649210363,
# doc:【左肺】上叶舌段、【右肺】中叶、双肺下叶散在【间质性】炎症基本吸收。
# 【右肺】中叶高密度细小结节未见明确显示。
# 气管前间隙与主肺动脉窗淋巴结未见明显增大。
# 余所见基本同前。
#
# doc_id:49705, score:2.408127122174262,
# doc:【右肺】下叶及【左肺】上叶高密度团块影，不除外恶性，纵隔淋巴结肿大。
# 双侧少量胸腔积液，左侧胸膜增厚。左侧叶间胸膜增厚。
# 双肺散在【间质性】肺炎、间质纤维化。
# 纵隔及【左肺】门多发钙化。
#
# doc_id:45748, score:2.408127122174262,
# doc:双肺散在炎症，【左肺】下叶【间质性】改变。【左肺】下叶及【右肺】上叶前段支气管牵拉扩张。
# 双侧胸腔少量积液，心包少许积液。
# 心脏体积增大，请结合相关检查。
# 腹部改变，建议完善腹部相关检查。
#
# doc_id:26850, score:2.4017063982747584,
# doc:【左肺】下叶炎症。
# 心影增大，左心室内小片状高密度影，请结合临床。
# 双侧胸腔积液，右侧为著；双肺多发【间质性】渗出。
# 双肺散在慢性炎症、气肿。【右肺】上叶钙化结节。
# 动脉硬化。
#
# doc_id:46136, score:2.401021809701745,
# doc:双肺间质纤维化并【间质性】肺炎同前。
# 【左肺】上叶舌段钙化小结节及下叶模糊小结节同前。
# 双侧胸膜增厚同前。
# 右侧第5前肋骨质形态不整，骨折愈合期改变，请结合临床及病史。
# 余所见基本同前。
#
# doc_id:49277, score:2.3999353098674394,
# doc:【右肺】下叶结节显示不清，双肺新发小结节。
# 双肺【间质性】肺炎较前略吸收化，部分间质纤维化较前无改变。
# 纵隔内多发增大淋巴结较前无改变。
# 余所见基本同前。
#
# doc_id:44302, score:2.3999353098674394,
# doc:双肺散在小结节较前无明显变化，随诊复查。
# 【右肺】下叶前基底段支气管囊状扩张改变同前。
# 双肺散在多发炎症（【间质性】炎症）大致同前。
# 余胸部所见基本同前。
#
# doc_id:37328, score:2.3999353098674394,
# doc:双肺多发渗出性病变，【右肺】下叶显著。
# 双侧少量胸腔积液。心脏左室增大。注意心功能不全，【间质性】肺水肿。
# 动脉硬化。
# 腹部改变，结合临床和腹部相关检查。
#
# doc_id:48087, score:2.3887129452524527,
# doc:【右肺】上叶炎症吸收。
# 【左肺】上叶新发渗出，注意少许炎症。
# 双肺下叶【间质性】病变范围缩小。
# 【左肺】上叶舌段、【右肺】中叶少许慢性炎症。
# 双侧少量胸腔积液或胸膜增厚。
# 余所见基本同前。
#
# doc_id:37449, score:2.3741930833793834,
# doc:双肺【间质性】炎症较前范围减少。
# 双侧胸腔积液，较前减少。
# 【左肺】上叶尖段纤维、增殖、钙化性病变同前。
# 【右肺】尖间隔旁型肺气肿及肺大疱同前。
# 腹部改变，请结合临床及相关检查。
#
# doc_id:32966, score:2.3741930833793834,
# doc:双肺多发【间质性】炎症可能性大。
# 【左肺】上叶尖段纤维、增殖、钙化性病变，考虑继发性肺结核。
# 【右肺】尖间隔旁型肺气肿及肺大疱。
# 双侧胸腔积液。
# 腹部改变，请结合临床及相关检查。
#
# doc_id:34684, score:2.3741930833793834,
# doc:双肺【间质性】炎症，双侧胸腔积液，同前未见明显变化。
# 【左肺】上叶尖段纤维、增殖、钙化性病变，继发型肺结核。
# 【右肺】尖间隔旁型肺气肿及肺大疱。
# 腹部改变，请结合临床及相关检查。
#
# doc_id:33496, score:2.3615713378496515,
# doc:左侧气胸基本吸收，左侧胸腔积液、【左肺】膨胀不良及炎症基本同前。
# 双肺散在小叶中心型及间隔旁型肺气肿同前。
# 双肺【间质性】改变，双肺下叶为著同前。
# 左侧第5-9后肋骨折同前。
# 余所见基本同前。
#
# doc_id:45061, score:2.3287565294410304,
# doc:双肺炎症，注意【间质性】炎症。
# 【右肺】中叶结节，随诊复查。
# 双侧胸腔少量积液，右叶间裂少量积液。
# 双肺小叶中心型肺气肿。
# 甲状腺右叶结节，请结合临床相关检查。
#
# doc_id:31848, score:2.3287565294410304,
# doc:双侧胸腔少许积液。
# 双肺【间质性】肺炎、间质纤维化。双肺少许炎症。
# 【右肺】上叶支气管轻度牵拉性扩张。
# 甲状腺改变，请结合专科检查。
# 腹部改变，请结合临床相关检查。
#
# doc_id:45207, score:2.3287565294410304,
# doc:【右肺】散在纤维增值、钙化性病变，注意除外继发型肺结核。
# 双肺散在慢性炎症（部分为【间质性】炎症）。
# 双肺散在间隔旁型及小叶中心型肺气肿。
# 双侧肋胸膜多发局灶增厚。
#
# doc_id:44999, score:2.3287565294410304,
# doc:双肺胸膜下【间质性】炎症，伴双肺下叶支气管扩张。
# 双肺多发结节，【右肺】下叶上段不整形结节，性质待定，建议短期复查。
# 双侧肋间胸膜局限性增厚。
# 纵隔多发稍大淋巴结。
#
# doc_id:43672, score:2.3240294772038124,
# doc:【右肺】下叶基底段空洞，恶性待除外。
# 【右肺】门及纵隔多发肿大淋巴结，不除外转移。
# 右侧胸膜结节增后，恶性不除外。
# 双肺胸膜下散在【间质性】肺炎。
# 右侧胸腔积液。
#
# doc_id:52674, score:2.3109440953878635,
# doc:【左肺】上叶病变，恶性不除外，建议增强检查。
# 双肺多发炎症，部分小叶间隔增高，注意【间质性】病变。
# 双肺钙化及非钙化小结节，注意复查。
# 双侧胸膜、右侧横隔胸膜限局性增厚，部分钙化。
# 冠脉及主动脉硬化。
#
# doc_id:38260, score:2.309842554000064,
# doc:双肺多发炎症，【右肺】中叶实变；注意双肺【间质性】改变。
# 双肺小叶中央型气肿。
# 双侧胸腔积液。
# 纵隔内多发增大淋巴结，请结合临床。
# 【右肺】上叶钙化、纤维化性病变。
#
# doc_id:52075, score:2.3014533530257144,
# doc:双肺【间质性】炎症较前略减轻。
# 【右肺】中叶外侧段支气管局部小囊状扩张基本同前。
# 纵隔间隙多发增大淋巴结基本同前。
# 双侧胸腔积液积液同前，右侧叶间裂积液未见确切显示。
#
# doc_id:27806, score:2.2935454257944397,
# doc:【右肺】下叶及【左肺】上叶近肺门支气管旁占位，性质待定，建议进一步增强检查。
# 【左肺】上叶不整形结节，性质待定，建议增强。
# 纵隔内多发淋巴结肿大。
# 双侧局限性胸膜增厚。
# 双肺散在慢性炎症、【间质性】改变。
#
# doc_id:36047, score:2.2880404497754565,
# doc:双肺散在多发炎症（【间质性】肺炎）。
# 【右肺】上叶尖段气管型支气管（先天变异）。
# 脂肪肝；胆囊术后改变；右肾囊肿。请结合腹部相关检查。
# 甲状腺改变，请结合临床及超声检查。
#
# doc_id:41293, score:2.2880404497754565,
# doc:【右肺】上叶尖段纤维钙化增殖病变。
# 双肺胸膜下【间质性】炎症。
# 双肺内钙化及非钙化结节，注意复查。
# 双肺散在气肿。
# 甲状腺改变请结合相关检查。
# 右肾占位，建议进一步检查。
#
# doc_id:47349, score:2.2616782628702063,
# doc:【右肺】下叶上段不整形结节，不排除恶性。
# 双肺胸膜下【间质性】炎症，伴双肺下叶支气管扩张同前。
# 双肺多发结节同前，建议定期复查。
# 纵隔多发稍大淋巴结同前。
# 余所见基本同前。
#
# doc_id:32541, score:2.2616782628702063,
# doc:双肺散在渗出性病变及【右肺】上叶实变影吸收减少。
# 右侧胸腔积液大部分吸收。
# 双肺【间质性】水肿好转，心脏体积稍增大，较前稍缩小。
# 动脉及冠脉钙化同前。
# 余胸部所见基本同前。
#
# doc_id:38500, score:2.2487236681114395,
# doc:【右肺】上叶胸膜下结节，炎性？注意复查。
# 双肺散在钙化、非钙化结节。
# 双肺多发气肿，双肺【间质性】改变，散在慢性炎症。
# 双侧胸膜多发增厚。
# 双肺门及纵隔淋巴结增大，结合临床。
#
# doc_id:52154, score:2.2487236681114395,
# doc:【右肺】上叶占位较前无明显变化。
# 双肺散在多发小结节，部分略增大。
# 双肺散在多发【间质性】渗出性病变较前未见明显变化。
# 左侧第4肋骨及右侧第6肋密度较前增高。
# 余所见基本同前。
#
# doc_id:51823, score:2.2412478553727446,
# doc:【左肺】恶性占位、胸膜转移、纵隔淋巴结转移？
# 左侧胸腔包裹性积液，【左肺】下叶肺组织膨胀不良。
# 双肺新增结节影，转移不除外。
# 双肺【间质性】病变内结节形成，不除外恶性。
# 骨性胸廓多发破坏，考虑转移。
# 腹部改变，请结合相关检查。
#
# doc_id:38313, score:2.2282145714102572,
# doc:双肺散在炎症、【间质性】肺改变，请结合临床。
# 【右肺】上叶小结节病变，考虑炎性。
# 少量心包积液，动脉硬化。
# 甲状腺右叶、峡部结节，请结合超声检查。
# 纵隔、【右肺】门淋巴结钙化。
#
# doc_id:33462, score:2.2232546493734464,
# doc:【右肺】上叶占位较前缩小，请结合临床。
# 双肺多发渗出性病变（以【间质性】渗出为主）。
# 气管隆突下增大淋巴结同前，气管前间隙淋巴结较前增大。
# 双侧胸腔积液较前增多。
# 余所见基本同前。
#
# doc_id:35371, score:2.2214996030382856,
# doc:左侧新增气胸，【左肺】上叶部分不张。
# 双肺多发炎症较前增多，部分实变范围较前增大。
# 【右肺】中叶内侧段【间质性】肺气肿较前略减少。
# 双肺门影较前增大，请结合临床。
# 双侧胸腔新增少量积液。
# 余所见基本同前。
#
# doc_id:46989, score:2.1933896639885537,
# doc:双肺【间质性】肺炎。
# 【左肺】舌段近前胸壁模糊片影，炎性？请结合临床，必要时复查除外占位。
# 双肺尖纤维增生性病变。
# 双肺多发钙化及非钙化结节病变。
# 双侧肋胸膜及横膈胸膜局部增厚伴钙化改变。
# 双侧少量胸腔积液。
# 动脉硬化。
#
# doc_id:26428, score:2.174009045825198,
# doc:双肺下叶支气管狭窄，请结合临床及相关检查。
# 【右肺】上叶尖段钙化、纤维化病变。
# 双肺多发【间质性】肺炎。
# 双肺多发小叶中心型、间隔旁型肺气肿。
# 肝囊肿可能大。
# 胆囊结石。
# 左肾囊肿可能大。
#
# doc_id:44244, score:2.162036643179285,
# doc:双肺多发结节，性质待定，密切随访复查。
# 双肺炎症并【间质性】改变。
# 双侧胸腔积液伴前方肺组织受压膨胀不良。
# 【右肺】上叶小叶中心型肺气肿。
# 纵隔淋巴结多发增大。
# 主动脉及冠状动脉壁钙化。
#
# doc_id:29640, score:2.150195383846794,
# doc:双肺散在钙化及非钙化小结节。
# 双肺散在慢性炎症，双肺下叶基底段胸膜下【间质性】改变。
# 双肺散在小叶中心型及间隔旁型肺气肿。
# 气管、右主支气管及【右肺】下叶支气管内痰栓？
# 主动脉及冠状动脉钙化。
#
# doc_id:49291, score:2.130166795016042,
# doc:双肺散在【间质性】炎症，部分间质纤维化，伴双肺下叶支气管轻度扩张。
# 【右肺】散在结节，炎性可能性大，建议随诊复查。
# 【左肺】上叶间隔旁型肺气肿。
# 冠脉钙化。
# 轻度脂肪肝，肝内钙化灶；左侧肾上腺结节；请结合腹部相关检查。
#
# doc_id:47423, score:2.127913069175208,
# doc:【右肺】下叶及上叶尖段、双肺胸膜下【间质性】炎症。
# 【右肺】上叶尖段磨玻璃密度病变，随诊复查。
# 双侧胸膜局限性增厚伴钙化。
# 动脉硬化。腹主动脉壁改变，请结合临床
# 甲状腺改变，请结合相关检查。
#
# doc_id:46821, score:2.126897769404715,
# doc:【右肺】散在结节，炎性肉芽肿？建议复查。
# 双侧胸壁胸膜下【间质性】肺炎？
# 双肺上叶间隔旁型肺气肿。
# 双侧第8-10肋前端骨质形态扭曲。
# 双侧肋胸膜局限增厚。
# 冠脉改变，术后，请结合临床及相关病史。
#
# doc_id:51113, score:2.126897769404715,
# doc:双肺少许慢性炎症及胸膜下轻度【间质性】改变，请结合临床。
# 【右肺】上叶少量小叶中心型及间隔旁型肺气肿。
# 左侧胸膜略增厚。
# 动脉硬化；冠脉支架置入术后改变。
# 左心室改变，请结合临床注意心梗后遗改变。
#
# doc_id:33675, score:2.1160041480225344,
# doc:【右肺】上叶前段病变，周边型肺癌可能性大（低分化腺癌），邻近部分支气管狭窄。
# 右侧【右肺】门、气管前间隙、颈间隙多发肿大淋巴结，注意转移。
# 双肺【间质性】炎症，伴蜂窝肺形成；双侧支气管牵拉扩张。
#
# doc_id:42702, score:2.1154372662856558,
# doc:双肺【间质性】炎症？
# 双肺间隔旁型肺气肿。
# 【右肺】中叶外侧段支气管局部小囊状扩张可能大。
# 纵隔间隙多发淋巴结略增大。
# 动脉硬化；心脏体积增大，请结合相关检查。
# 双侧少量胸腔积液，右侧少量叶间积液。
#
# doc_id:27414, score:2.1154372662856558,
# doc:双肺【间质性】病变基本同前。
# 双肺散在融合小叶中心性及泡性肺气肿，伴肺大疱形成同前。
# 【右肺】上叶结节及中叶小结节未见确切显示。
# 气管旁含气囊肿基本同前。
# 余所见基本同前。
# 腹部改变，参见腹部检查。
#
# doc_id:45149, score:2.104099607998942,
# doc:双肺【间质性】炎症较前稍加重。
# 双肺间隔旁型肺气肿同前。
# 【右肺】中叶外侧段支气管局部小囊状扩张基本同前。
# 纵隔间隙多发增大淋巴结基本同前。
# 双侧胸腔积液、右侧叶间积液较前减少。
# 余胸部所见基本同前。
#
# doc_id:43499, score:2.104099607998942,
# doc:【右肺】下叶新发实变，余双肺内炎症渗出较前稍减少。
# 右侧胸腔积液较前增多，邻近肺组织膨胀不良；左侧胸腔少量积液较前减少。
# 双肺多发炎症伴【间质性】改变。
# 余胸部所见基本同前。
# 腹部改变请结合相关检查。
#
# doc_id:37809, score:2.0954456743845253,
# doc:【左肺】下叶不整形团块影，肺膨胀不良？占位不除外。
# 双肺多叶段散在炎症，【间质性】改变。
# 双肺散在钙化及非钙化小结节，注意复查。
# 左侧胸腔积液，双侧胸腔局部增厚。
# 主支气管、【左肺】主支气管及舌段支气管痰液？
# 动脉硬化。
# 甲状腺病变，请结合相关专科检查。
#
# doc_id:52171, score:2.09288282991816,
# doc:1、双肺野透过度不均匀、双肺胸膜下区【间质性】炎症较前无明显变化。
# 2、【右肺】下叶后底段局部支气管扩张、局灶慢性炎症同前。
# 3、右侧胸腔少量积液较前减少。
# 4、食管裂孔疝同前。
# 5、余所见基本同前。
#
# doc_id:49649, score:2.0721113693452216,
# doc:【左肺】门纵隔旁肿块同前，符合恶性，伴【左肺】门及纵隔淋巴结转移及邻近结构受累。
# 【左肺】上叶及胸膜下结节同前，转移？
# 【右肺】胸膜下散在细小结节同前，良性可能性大，建议复查。
# 双肺胸膜下散在【间质性】病变、双肺散在小叶中心型肺气肿同前。
# 余所见基本同前。
#
# doc_id:35937, score:2.049248395206325,
# doc:【右肺】下叶基底段新增少许炎症，注意【间质性】病变。
# 【左肺】上叶下舌段、下叶上段及【右肺】中叶内侧段少许炎症基本同前。
# 【右肺】上叶细小结节，随诊复查。
# 双肺上叶间隔旁型肺气肿，【右肺】下叶基底段泡性气肿同前。
# 余所见基本同前。
#
# doc_id:48493, score:2.049186662769042,
# doc:双肺【间质性】炎症密度较前升高，较前稍加重。
# 双肺间隔旁型肺气肿同前。
# 【右肺】中叶外侧段支气管局部小囊状扩张基本同前。
# 纵隔间隙多发增大淋巴结基本同前。
# 双侧胸腔积液、右侧叶间积液同前。
# 余胸部所见基本同前。
#
# doc_id:38481, score:2.0460473776236907,
# doc:双肺【间质性】炎症，【右肺】上叶部分肺组织实变，请结合临床抗炎治疗后复查。
# 【左肺】下叶上段钙化结节。
# 双肺散在气肿。
# 双侧胸膜局限增厚或胸腔少量积液不除外。
# 肝脏密度减低，请结合临床及相关检查。
# 双侧甲状腺改变，请结合临床及相关检查。
#
# doc_id:32667, score:1.9828035523167624,
# doc:【右肺】门、纵隔间隙、腹膜后间隙多发肿大淋巴结，不除外淋巴瘤，建议浅表淋巴结活检。
# 双肺多发结节同前。
# 双肺散在【间质性】改变，淋巴管炎？
# 左舌段及【右肺】下叶基底段支气管扩张。
# 右锁骨改变，请结合临床及相关病史。
#
# doc_id:41895, score:1.9777107606609725,
# doc:【右肺】上叶新增占位，恶性？
# 纵隔淋巴结稍肿大。
# 双肺新增散在炎症，余双肺【间质性】病变及渗出性病变较前未见明显改变。
# 【左肺】上叶尖后胸膜下小结节，请随诊复查。
# 心脏改变，基本同前。心包积液较前略减少。
# 双侧胸腔胸腔积液较前增多。
# 余所见基本同前。
#
# doc_id:49480, score:1.9769540935375978,
# doc:【右肺】下叶后基底段结节较前增大，性质待定，建议结合实验室检查，必要时活检。
# 余双肺散在钙化及非钙化小结节病变无明显变化。
# 双肺【间质性】炎症较前未见明显变化。
# 双侧胸膜多发结节状增厚、部分钙化无变化。
# 余所见基本同前。
#
# doc_id:51575, score:1.9769540935375978,
# doc:双肺【间质性】肺炎，【右肺】水平裂旁炎症较前吸收。
# 双肺上叶纤维、钙化性病变较前无明显变化。
# 双肺多发小叶中心型及间隔旁型气肿同前。
# 右侧胸腔少量积液基本吸收，双侧胸膜增厚伴钙化。
# 动脉及冠脉硬化同前。
# 余胸部所见基本同前。
#
# doc_id:31785, score:1.9675115804934937,
# doc:【左肺】下叶前底段支气管壁增厚，伴管腔内粘液栓？性质待定，结合临床。
# 【左肺】下叶基底段小结节，气管内粘液栓？
# 双肺多发【间质性】改变。双肺多发间隔旁型及小叶中心型气肿。
# 双侧胸膜多发伴钙化，部分邻近支气管受牵拉略扩张。
# 主动脉壁及冠状动脉壁多发钙化。
# 肝囊肿？请结合腹部相关检查。
#
# doc_id:37040, score:1.9475329485344708,
# doc:双肺下叶【间质性】炎症、渗出较前稍增多。
# 双肺上叶纤维、增殖病灶基本同前。
# 【右肺】下叶前底段小结节较前稍缩小。
# 双肺少许慢性炎症基本同前。
# 双肺多发气肿同前。
# 双侧胸膜多发增厚、钙化；双肺叶间胸膜稍厚。
# 腹部改变，结合腹部检查。
#
# doc_id:35917, score:1.9096404427161227,
# doc:双肺【间质性】病变较前略吸收。
# 双肺散在慢性炎症基本同前。
# 双肺小叶中心型、全小叶型及间隔旁型肺气肿同前。
# 【右肺】上叶纤维、增生、钙化性病变同前，建议进一步除外继发性肺结核。
# 右侧腋窝淋巴结较前减小。
# 心包少许积液。
# 余所见基本同前。
#
# doc_id:38001, score:1.9055933747891713,
# doc:1.双肺（胸膜下区分布为主）散在慢性（【间质性】）炎症。
# 2.【右肺】上叶尖段及【左肺】下叶基底段不整形小结节影，局灶性慢性炎症。
# 3.【左肺】上叶间隔旁型肺气肿。
# 4.左侧肋/膈胸膜增厚、膈胸膜钙化，【左肺】下叶肺内慢性炎症。
# 5.冠脉钙化；心包少量积液。
# 6.肝内多发稍低密度病变，性质待定。
#
# doc_id:46133, score:1.8880163413938544,
# doc:1、【右肺】中叶及【左肺】上叶下舌段少许慢性炎症。
# 2、【右肺】中叶水平叶间胸膜下及下叶后底段（Im:35、20显示）细小结节影，肉芽肿性病变。
# 3、双肺下叶背侧胸膜下模糊影，坠积效应所致或【间质性】病变。
# 4、双肺侧叶间胸膜局部略增厚。
# 5、肝内小囊肿可能性大。
#
# doc_id:43587, score:1.8622032606740826,
# doc:1、双侧仍见胸腔积液，右侧为著；双肺【间质性】肺水肿仍大致同前。
# 3、动脉硬化同前；瓣膜钙化同前；左心系统增大、心包少量积液同前。
# 4、【左肺】上叶细小钙化结节灶同前。
# 5、纵隔间隙淋巴结稍增大，伴【右肺】门淋巴结钙化基本同前。
# 6、双侧甲状腺改变同前。
# 7、余所见基本同前。
#
# doc_id:46187, score:1.8374382756885659,
# doc:【右肺】下叶肺门旁及【左肺】上叶占位性病变，恶性可能性大。
# 双肺弥漫性结节，转移瘤?
# 双肺间质增厚，癌性淋巴管炎？【间质性】肺炎？
# 纵隔及双肺门淋巴结肿大，淋巴结转移可能大。
# 双侧胸膜不均匀增厚，注意转移。
# 双侧胸腔积液，右侧叶间积液。
# 心包积液。
# 肝脏病变，建议进一步检查。
#
# doc_id:39767, score:1.811639604649604,
# doc:【右肺】下叶脊柱旁占位，恶性可能性大。
# 双肺胸膜下少量小结节，性质待定。
# 双肺【间质性】肺炎改变，请结合临床。
# 【右肺】上叶尖后段纹理紊乱，伴不规则斑片及斑条影，必要时随访复查。
# 右侧少量胸腔积液。
# 少量心包积液；动脉硬化。
# 甲状腺改变，请结合专科检查。
#
# doc_id:36181, score:1.7576881075231192,
# doc:左侧胸腔积液较前增多，左叶间裂积液，【左肺】组织受压膨胀不良。
# 【左肺】下叶实变范围较前增大；【右肺】上叶新增炎症；建议继续抗炎治疗。
# 双肺下叶【间质性】渗出性病变较前吸收、减少。
# 双肺多发小叶中心型肺气肿同前。
# 【右肺】中叶内侧段结节较前未见明显变化。
# 双侧胸膜增厚伴钙化同前。
# 心包积液同前。
# 余所见基本同前。
#
# doc_id:51484, score:1.6975993279595862,
# doc:【右肺】下叶少许慢性炎症较前减少。
# 双肺小叶间隔增厚、叶间胸膜增厚、【右肺】中叶少许炎症、中叶间隔旁肺气肿同前。
# 双肺渗出病变、心衰、【间质性】肺水肿、心包积液较前增多。双肺下叶胸膜增厚或胸腔少量积液同前。
# 主动脉壁稍厚，请结合临床。
# 腹部所见请结合腹部相关检查。
# 余所见基本同前。
#
# doc_id:23710, score:1.6878006283479883,
# doc:结合本院2017-02-16胸部CT平扫(1011718447)：
# 【右肺】下叶前底段叶间裂旁分叶状肿块较前无明显变化，大小约2.9cm×1.9cm，【左肺】上叶尖后段致密钙化灶同前。双肺多发磨玻璃密度斑片影密度较前增高、范围较前增大，仍以【间质性】渗出为主。
# 纵隔间隙仍可见多发肿大淋巴结。
# 余所见基本同前。
#
# doc_id:34484, score:1.6673023175500046,
# doc:1、慢性支气管炎合并感染改变（弥漫小叶中心型及全小叶型肺气肿、肺大疱）。【右肺】中叶肺大疱？气胸？
# 2、双肺【间质性】肺炎伴间质纤维化，【右肺】为著；【左肺】上叶后段钙化结节。
# 3、纵隔右移；双侧胸膜局限增厚；右侧胸腔胸腔积液。
# 4、动脉硬化。
# 5、右主支气管内结节，痰栓？
# 6、甲状腺右叶改变，请结合临床及专科检查。
#
# doc_id:50115, score:1.5970255571338796,
# doc:后纵隔、【右肺】门旁占位，纵隔、肺门多增大淋巴结，恶性可能大，建议进一步胸部增强CT检查。
# 双肺小叶中心型气肿，间隔旁型气肿、泡性气肿。
# 【右肺】下叶见钙化结节。
# 【左肺】下叶炎症，注意【左肺】下叶【间质性】炎症。
# 主动脉及冠脉管壁多发钙化灶。
# 右侧颈部占位，不除外转移，请结合颈部相关检查。
# 左肾上腺区占位，建议进一步腹部检查。
# 腰1椎体低密度灶，性质待定。
#
# doc_id:44455, score:1.5567504533817562,
# doc:【右肺】上叶后段不整结节大致同前，周围渗出稍减少，不除外恶性。
# 纵隔多发稍大及增大淋巴结，伴钙化同前。
# 右侧第8肋骨骨质破坏、软组织肿块形成；右侧第5、6肋骨骨质密度不均，注意骨转移。
# 【左肺】上叶小结节基本同前。
# 双肺散在渗出、炎症基本同前，【右肺】【间质性】病变及部分蜂窝气肿改变基本同前。
# 右侧胸腔包裹性积液基本同前。
# 纵隔右移同前，请结合临床。
#
# doc_id:43723, score:1.5165806624635563,
# doc:【右肺】中叶不张，支气管截断，周围软组织肿块，注意中央型肺癌。
# 【右肺】下叶支气管周围增厚，远端小叶间隔不规则增厚，注意癌性淋巴管炎。
# 【右肺】门、纵隔淋巴结肿大融合，注意转移。
# 双肺散在纤维、增殖及钙化性病变，不除外继发结核所致。
# 双肺【间质性】病变，注意部分间质纤维化。
# 双肺散在肺气肿。
# 双侧胸腔积液；【右肺】叶间积液。
#
# doc_id:40109, score:1.499923047119273,
# doc:【左肺】下叶肿块，考虑为周围型肺癌可能大，纵隔间隙及双肺门多发肿大淋巴结，请结合临床，必要时活检。
# 【左肺】下叶结节，恶性可能大。
# 【右肺】中叶胸膜下结节，性质待定。【右肺】上叶胸膜增厚伴钙化。
# 双肺散在炎症，部分为【间质性】炎症。双肺胸膜下散在泡性气肿。
# 左主支气管内高密度影，痰栓？
# 左锁骨下动脉起始部狭窄，伴腹壁血栓。
# 右锁骨内固定术后改变，请结合病史。
# 右侧第9肋高密度结节，请结合临床。
#
# doc_id:7123, score:1.3699022783913948,
# doc:结合本院2016-10-07前片（1010933596）：
# 【右肺】上叶纵隔旁类圆形肿块较前明显缩小，大小约为1.6cm×1.9cm，双肺内多发模糊斑片影，部分为【间质性】渗出。双侧胸腔背侧液性密度影较前略增多，双肺下叶散在模糊条片影基本同前，余双肺野透过度良好，肺纹理清晰，走行正常。肺门影不大。气管及各支气管通畅。
# 气管隆突下增大淋巴结影基本同前，气管前间隙淋巴结较前增大。
# 余所见基本同前。

# %%
# 关键词检索，不打印结果，仅显示条数及查询时间
q = '条状钙化影'
mr.rener_research_result(q,result_print=False)
# Out:
# The length of results is  6
# 【search】time cost: 0.0009911060333251953 s
